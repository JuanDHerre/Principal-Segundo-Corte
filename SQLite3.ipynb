# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanDHerre/Principal-Segundo-Corte/blob/main/SQLite3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Base de datos

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 0s (1,948 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sqlite3.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# Mostrar productos

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Artículo1', 'Electrónica', 402.17, 60, 'Proveedor2', '2023-09-19', 'Almacén C')
# (2, 'Objeto2', 'Deportes', 227.13, 61, 'Proveedor1', '2023-07-17', 'Almacén A')
# (3, 'Producto3', 'Moda', 498.68, 81, 'Proveedor1', '2023-02-04', 'Almacén B')
# (4, 'Objeto4', 'Hogar', 393.92, 56, 'Proveedor1', '2023-07-04', 'Almacén B')
# (5, 'Artículo5', 'Jardín', 287.13, 1, 'Proveedor1', '2023-01-10', 'Almacén A')
# (6, 'Artículo6', 'Hogar', 42.26, 33, 'Proveedor3', '2023-08-20', 'Almacén B')
# (7, 'Artículo7', 'Jardín', 355.15, 94, 'Proveedor1', '2023-11-24', 'Almacén B')
# (8, 'Artículo8', 'Hogar', 230.68, 45, 'Proveedor3', '2023-06-06', 'Almacén B')
# (9, 'Artículo9', 'Electrónica', 395.46, 44, 'Proveedor2', '2023-10-22', 'Almacén C')
# (10, 'Artículo10', 'Moda', 153.63, 93, 'Proveedor1', '2023-03-19', 'Almacén B')
# (11, 'Producto11', 'Deportes', 404.47, 94, 'Proveedor1', '2023-08-01', 'Almacén B')
# (12, 'Producto12', 'Jardín', 87.83, 82, 'Proveedor2', '2023-11-14', 'Almacén B')
# (13, 'Producto13', 'Jardín', 433.63, 4, 'Proveedor2', '2023-11-22', 'Almacén A')
# (14, 'Objeto14', 'Deportes', 464.14, 26, 'Proveedor2', '2023-02-24', 'Almacén B')
# (15, 'Objeto15', 'Electrónica', 138.76, 54, 'Proveedor1', '2023-11-03', 'Almacén A')
# (16, 'Objeto16', 'Deportes', 272.67, 75, 'Proveedor1', '2023-10-04', 'Almacén C')
# (17, 'Producto17', 'Deportes', 423.6, 78, 'Proveedor1', '2023-02-07', 'Almacén A')
# (18, 'Objeto18', 'Jardín', 415, 83, 'Proveedor1', '2023-06-02', 'Almacén A')
# (19, 'Artículo19', 'Hogar', 59.98, 85, 'Proveedor3', '2023-07-27', 'Almacén C')
# (20, 'Objeto20', 'Deportes', 90.71, 90, 'Proveedor3', '2023-02-19', 'Almacén A')
# (21, 'Producto21', 'Deportes', 196.71, 72, 'Proveedor1', '2023-07-17', 'Almacén C')
# (22, 'Objeto22', 'Moda', 40.13, 13, 'Proveedor1', '2023-02-23', 'Almacén C')
# (23, 'Producto23', 'Hogar', 383.56, 46, 'Proveedor1', '2023-08-06', 'Almacén C')
# (24, 'Objeto24', 'Hogar', 60.86, 56, 'Proveedor3', '2023-11-15', 'Almacén C')
# (25, 'Artículo25', 'Jardín', 217.34, 90, 'Proveedor3', '2023-07-12', 'Almacén B')
# (26, 'Producto26', 'Jardín', 311.29, 34, 'Proveedor1', '2023-01-13', 'Almacén C')
# (27, 'Objeto27', 'Moda', 137.25, 98, 'Proveedor1', '2023-08-16', 'Almacén B')
# (28, 'Producto28', 'Jardín', 483.15, 57, 'Proveedor1', '2023-11-22', 'Almacén A')
# (29, 'Artículo29', 'Electrónica', 25.54, 77, 'Proveedor1', '2023-07-10', 'Almacén B')
# (30, 'Objeto30', 'Jardín', 35.58, 81, 'Proveedor1', '2023-01-03', 'Almacén A')
# (31, 'Producto31', 'Electrónica', 225.31, 95, 'Proveedor1', '2023-02-18', 'Almacén A')
# (32, 'Artículo32', 'Electrónica', 85.28, 59, 'Proveedor1', '2023-10-04', 'Almacén B')
# (33, 'Objeto33', 'Jardín', 61.29, 28, 'Proveedor3', '2023-04-03', 'Almacén A')
# (34, 'Artículo34', 'Jardín', 235.62, 62, 'Proveedor3', '2023-11-23', 'Almacén B')
# (35, 'Objeto35', 'Moda', 336.88, 29, 'Proveedor1', '2023-06-22', 'Almacén C')
# (36, 'Artículo36', 'Deportes', 490.18, 80, 'Proveedor3', '2023-04-18', 'Almacén A')
# (37, 'Artículo37', 'Electrónica', 368.23, 88, 'Proveedor3', '2023-10-22', 'Almacén B')
# (38, 'Producto38', 'Electrónica', 271.57, 6, 'Proveedor3', '2023-01-17', 'Almacén C')
# (39, 'Objeto39', 'Hogar', 353.76, 50, 'Proveedor2', '2023-09-02', 'Almacén A')
# (40, 'Objeto40', 'Moda', 267.84, 41, 'Proveedor2', '2023-04-17', 'Almacén A')
# (41, 'Artículo41', 'Moda', 428.68, 67, 'Proveedor2', '2023-02-23', 'Almacén B')
# (42, 'Artículo42', 'Deportes', 228.82, 41, 'Proveedor3', '2023-11-11', 'Almacén B')
# (43, 'Objeto43', 'Hogar', 56.65, 45, 'Proveedor3', '2023-07-20', 'Almacén A')
# (44, 'Producto44', 'Deportes', 243.86, 98, 'Proveedor1', '2023-07-24', 'Almacén A')
# (45, 'Producto45', 'Deportes', 193.64, 31, 'Proveedor1', '2023-08-13', 'Almacén C')
# (46, 'Producto46', 'Hogar', 97.28, 86, 'Proveedor1', '2023-10-13', 'Almacén B')
# (47, 'Producto47', 'Hogar', 142.24, 42, 'Proveedor3', '2023-04-01', 'Almacén C')
# (48, 'Objeto48', 'Moda', 67.53, 5, 'Proveedor2', '2023-03-10', 'Almacén B')
# (49, 'Producto49', 'Moda', 227.98, 34, 'Proveedor2', '2023-04-15', 'Almacén A')
# (50, 'Objeto50', 'Hogar', 373.07, 64, 'Proveedor1', '2023-02-13', 'Almacén C')
# (51, 'Producto51', 'Electrónica', 324.95, 71, 'Proveedor3', '2023-05-03', 'Almacén C')
# (52, 'Artículo52', 'Deportes', 116.71, 51, 'Proveedor2', '2023-12-22', 'Almacén C')
# (53, 'Artículo53', 'Jardín', 47.8, 87, 'Proveedor1', '2023-02-24', 'Almacén C')
# (54, 'Objeto54', 'Hogar', 144.63, 23, 'Proveedor3', '2023-03-23', 'Almacén C')
# (55, 'Producto55', 'Electrónica', 44.53, 51, 'Proveedor2', '2023-05-27', 'Almacén C')
# (56, 'Artículo56', 'Electrónica', 147.2, 73, 'Proveedor3', '2023-05-08', 'Almacén A')
# (57, 'Artículo57', 'Moda', 377.18, 40, 'Proveedor2', '2023-09-17', 'Almacén A')
# (58, 'Artículo58', 'Hogar', 24.23, 89, 'Proveedor1', '2023-10-22', 'Almacén C')
# (59, 'Objeto59', 'Hogar', 16.28, 8, 'Proveedor3', '2023-08-07', 'Almacén C')
# (60, 'Artículo60', 'Deportes', 29.93, 49, 'Proveedor3', '2023-05-26', 'Almacén A')
# (61, 'Objeto61', 'Jardín', 181.88, 5, 'Proveedor1', '2023-09-07', 'Almacén C')
# (62, 'Producto62', 'Moda', 498.59, 7, 'Proveedor2', '2023-12-11', 'Almacén B')
# (63, 'Producto63', 'Hogar', 344.82, 94, 'Proveedor1', '2023-08-27', 'Almacén B')
# (64, 'Objeto64', 'Hogar', 481.92, 79, 'Proveedor3', '2023-05-12', 'Almacén A')
# (65, 'Artículo65', 'Hogar', 84.74, 99, 'Proveedor1', '2023-07-04', 'Almacén B')
# (66, 'Artículo66', 'Electrónica', 14.81, 48, 'Proveedor3', '2023-08-14', 'Almacén B')
# (67, 'Artículo67', 'Moda', 136.96, 80, 'Proveedor1', '2023-03-11', 'Almacén A')
# (68, 'Objeto68', 'Deportes', 177.11, 72, 'Proveedor2', '2023-02-09', 'Almacén C')
# (69, 'Objeto69', 'Jardín', 283.1, 70, 'Proveedor3', '2023-06-02', 'Almacén B')
# (70, 'Artículo70', 'Jardín', 235.96, 37, 'Proveedor2', '2023-06-04', 'Almacén A')
# (71, 'Producto71', 'Moda', 178.22, 93, 'Proveedor1', '2023-07-11', 'Almacén C')
# (72, 'Artículo72', 'Deportes', 262.85, 96, 'Proveedor1', '2023-11-08', 'Almacén B')
# (73, 'Artículo73', 'Hogar', 486.71, 37, 'Proveedor2', '2023-11-20', 'Almacén C')
# (74, 'Objeto74', 'Moda', 477.33, 86, 'Proveedor3', '2023-05-02', 'Almacén C')
# (75, 'Artículo75', 'Hogar', 428.43, 32, 'Proveedor1', '2023-02-01', 'Almacén A')
# (76, 'Producto76', 'Jardín', 361.61, 50, 'Proveedor2', '2023-04-02', 'Almacén C')
# (77, 'Objeto77', 'Deportes', 429.3, 95, 'Proveedor3', '2023-05-28', 'Almacén B')
# (78, 'Objeto78', 'Moda', 142.43, 83, 'Proveedor2', '2023-05-12', 'Almacén C')
# (79, 'Artículo79', 'Hogar', 56.46, 49, 'Proveedor3', '2023-10-23', 'Almacén A')
# (80, 'Objeto80', 'Deportes', 12.92, 37, 'Proveedor2', '2023-07-20', 'Almacén C')
# (81, 'Artículo81', 'Electrónica', 97.52, 33, 'Proveedor1', '2023-07-09', 'Almacén A')
# (82, 'Producto82', 'Deportes', 171, 38, 'Proveedor3', '2023-06-23', 'Almacén B')
# (83, 'Producto83', 'Jardín', 188.39, 34, 'Proveedor1', '2023-11-20', 'Almacén C')
# (84, 'Artículo84', 'Electrónica', 349.13, 90, 'Proveedor2', '2023-04-24', 'Almacén C')
# (85, 'Producto85', 'Hogar', 243.39, 77, 'Proveedor2', '2023-10-18', 'Almacén A')
# (86, 'Objeto86', 'Deportes', 147, 47, 'Proveedor2', '2023-12-22', 'Almacén A')
# (87, 'Objeto87', 'Jardín', 460.02, 53, 'Proveedor3', '2023-12-23', 'Almacén C')
# (88, 'Objeto88', 'Hogar', 399.58, 8, 'Proveedor2', '2023-09-18', 'Almacén B')
# (89, 'Objeto89', 'Moda', 123.78, 100, 'Proveedor2', '2023-03-16', 'Almacén B')
# (90, 'Artículo90', 'Hogar', 133.6, 16, 'Proveedor3', '2023-08-14', 'Almacén B')
# (91, 'Objeto91', 'Hogar', 157.2, 41, 'Proveedor1', '2023-02-27', 'Almacén C')
# (92, 'Artículo92', 'Jardín', 17.59, 35, 'Proveedor3', '2023-01-21', 'Almacén C')
# (93, 'Artículo93', 'Moda', 384.38, 22, 'Proveedor1', '2023-09-24', 'Almacén A')
# (94, 'Producto94', 'Deportes', 179.29, 10, 'Proveedor3', '2023-07-26', 'Almacén C')
# (95, 'Producto95', 'Hogar', 357.11, 67, 'Proveedor3', '2023-12-12', 'Almacén C')
# (96, 'Artículo96', 'Moda', 403.11, 77, 'Proveedor3', '2023-09-14', 'Almacén A')
# (97, 'Artículo97', 'Moda', 104.71, 1, 'Proveedor2', '2023-03-17', 'Almacén C')
# (98, 'Producto98', 'Deportes', 102.56, 16, 'Proveedor1', '2023-12-19', 'Almacén C')
# (99, 'Objeto99', 'Deportes', 260.95, 18, 'Proveedor3', '2023-07-27', 'Almacén C')
# (100, 'Producto100', 'Moda', 200.49, 59, 'Proveedor1', '2023-12-04', 'Almacén A')
# (101, 'Objeto101', 'Electrónica', 25.32, 83, 'Proveedor1', '2023-08-26', 'Almacén A')
# (102, 'Artículo102', 'Moda', 349.91, 3, 'Proveedor1', '2023-12-08', 'Almacén A')
# (103, 'Objeto103', 'Jardín', 408.48, 10, 'Proveedor3', '2023-12-07', 'Almacén A')
# (104, 'Objeto104', 'Electrónica', 31.57, 96, 'Proveedor1', '2023-04-13', 'Almacén A')
# (105, 'Objeto105', 'Moda', 470.92, 20, 'Proveedor3', '2023-03-24', 'Almacén B')
# (106, 'Objeto106', 'Jardín', 363.94, 38, 'Proveedor1', '2023-01-11', 'Almacén B')
# (107, 'Producto107', 'Electrónica', 245.08, 11, 'Proveedor1', '2023-10-01', 'Almacén A')
# (108, 'Objeto108', 'Jardín', 458.58, 67, 'Proveedor1', '2023-02-21', 'Almacén A')
# (109, 'Objeto109', 'Electrónica', 132.64, 68, 'Proveedor2', '2023-05-18', 'Almacén C')
# (110, 'Producto110', 'Moda', 229.25, 53, 'Proveedor3', '2023-01-28', 'Almacén C')
# (111, 'Producto111', 'Deportes', 373.48, 65, 'Proveedor3', '2023-03-20', 'Almacén B')
# (112, 'Objeto112', 'Electrónica', 73.98, 92, 'Proveedor3', '2023-05-04', 'Almacén A')
# (113, 'Objeto113', 'Electrónica', 119.41, 50, 'Proveedor2', '2023-12-28', 'Almacén A')
# (114, 'Producto114', 'Deportes', 196.24, 43, 'Proveedor2', '2023-04-05', 'Almacén B')
# (115, 'Artículo115', 'Jardín', 336.15, 18, 'Proveedor1', '2023-05-19', 'Almacén B')
# (116, 'Objeto116', 'Electrónica', 454.96, 11, 'Proveedor3', '2023-05-11', 'Almacén B')
# (117, 'Objeto117', 'Electrónica', 232.58, 12, 'Proveedor1', '2023-02-19', 'Almacén A')
# (118, 'Objeto118', 'Moda', 320.9, 86, 'Proveedor3', '2023-03-28', 'Almacén B')
# (119, 'Artículo119', 'Hogar', 487.63, 27, 'Proveedor1', '2023-12-19', 'Almacén A')
# (120, 'Artículo120', 'Deportes', 307.72, 63, 'Proveedor1', '2023-07-20', 'Almacén C')
# (121, 'Objeto121', 'Hogar', 362.1, 53, 'Proveedor2', '2023-06-17', 'Almacén A')
# (122, 'Producto122', 'Deportes', 306.89, 78, 'Proveedor2', '2023-01-21', 'Almacén A')
# (123, 'Producto123', 'Moda', 474.8, 29, 'Proveedor3', '2023-04-21', 'Almacén A')
# (124, 'Objeto124', 'Deportes', 447.56, 78, 'Proveedor3', '2023-07-22', 'Almacén B')
# (125, 'Objeto125', 'Moda', 410.79, 95, 'Proveedor2', '2023-02-12', 'Almacén C')
# (126, 'Producto126', 'Moda', 179.56, 16, 'Proveedor3', '2023-12-28', 'Almacén B')
# (127, 'Producto127', 'Electrónica', 329.46, 97, 'Proveedor2', '2023-12-24', 'Almacén A')
# (128, 'Producto128', 'Hogar', 485.45, 83, 'Proveedor2', '2023-12-01', 'Almacén A')
# (129, 'Artículo129', 'Moda', 381.66, 73, 'Proveedor1', '2023-04-25', 'Almacén A')
# (130, 'Objeto130', 'Deportes', 30.5, 59, 'Proveedor1', '2023-07-25', 'Almacén B')
# (131, 'Producto131', 'Deportes', 177.06, 59, 'Proveedor1', '2023-06-06', 'Almacén C')
# (132, 'Objeto132', 'Moda', 434.7, 48, 'Proveedor3', '2023-01-25', 'Almacén C')
# (133, 'Objeto133', 'Jardín', 399.55, 8, 'Proveedor3', '2023-03-15', 'Almacén B')
# (134, 'Producto134', 'Hogar', 37.75, 5, 'Proveedor2', '2023-01-04', 'Almacén B')
# (135, 'Producto135', 'Hogar', 142.23, 21, 'Proveedor3', '2023-10-10', 'Almacén B')
# (136, 'Objeto136', 'Electrónica', 428.93, 19, 'Proveedor3', '2023-11-15', 'Almacén B')
# (137, 'Producto137', 'Deportes', 41.16, 46, 'Proveedor2', '2023-08-20', 'Almacén C')
# (138, 'Objeto138', 'Deportes', 381.88, 80, 'Proveedor2', '2023-09-28', 'Almacén B')
# (139, 'Objeto139', 'Jardín', 64.23, 29, 'Proveedor2', '2023-12-06', 'Almacén C')
# (140, 'Objeto140', 'Moda', 477.08, 82, 'Proveedor2', '2023-10-26', 'Almacén B')
# (141, 'Producto141', 'Hogar', 167.43, 3, 'Proveedor2', '2023-06-16', 'Almacén A')
# (142, 'Producto142', 'Jardín', 431.92, 95, 'Proveedor3', '2023-07-19', 'Almacén A')
# (143, 'Producto143', 'Hogar', 464.75, 24, 'Proveedor2', '2023-02-09', 'Almacén B')
# (144, 'Producto144', 'Deportes', 391.5, 8, 'Proveedor1', '2023-01-13', 'Almacén B')
# (145, 'Producto145', 'Moda', 162.47, 22, 'Proveedor3', '2023-10-14', 'Almacén B')
# (146, 'Objeto146', 'Moda', 162.87, 83, 'Proveedor3', '2023-07-07', 'Almacén A')
# (147, 'Producto147', 'Moda', 303, 3, 'Proveedor2', '2023-05-05', 'Almacén B')
# (148, 'Artículo148', 'Deportes', 496.64, 95, 'Proveedor2', '2023-02-09', 'Almacén C')
# (149, 'Objeto149', 'Deportes', 226.69, 83, 'Proveedor1', '2023-07-26', 'Almacén A')
# (150, 'Producto150', 'Deportes', 490.63, 17, 'Proveedor2', '2023-11-05', 'Almacén C')
# (151, 'Objeto151', 'Moda', 167.74, 96, 'Proveedor1', '2023-07-25', 'Almacén B')
# (152, 'Artículo152', 'Jardín', 484.09, 84, 'Proveedor1', '2023-05-18', 'Almacén A')
# (153, 'Objeto153', 'Hogar', 483.73, 10, 'Proveedor1', '2023-08-09', 'Almacén B')
# (154, 'Producto154', 'Deportes', 176.99, 54, 'Proveedor2', '2023-12-19', 'Almacén A')
# (155, 'Objeto155', 'Jardín', 380.85, 52, 'Proveedor1', '2023-04-14', 'Almacén B')
# (156, 'Artículo156', 'Jardín', 327.41, 51, 'Proveedor1', '2023-06-15', 'Almacén C')
# (157, 'Artículo157', 'Moda', 266.98, 53, 'Proveedor3', '2023-03-20', 'Almacén C')
# (158, 'Producto158', 'Hogar', 56.77, 75, 'Proveedor3', '2023-07-09', 'Almacén C')
# (159, 'Producto159', 'Electrónica', 272.92, 15, 'Proveedor2', '2023-08-02', 'Almacén C')
# (160, 'Objeto160', 'Deportes', 398.39, 95, 'Proveedor2', '2023-08-08', 'Almacén B')
# (161, 'Artículo161', 'Moda', 422.19, 89, 'Proveedor1', '2023-08-20', 'Almacén C')
# (162, 'Artículo162', 'Electrónica', 16.25, 37, 'Proveedor3', '2023-10-26', 'Almacén A')
# (163, 'Artículo163', 'Jardín', 462.17, 78, 'Proveedor3', '2023-10-21', 'Almacén A')
# (164, 'Objeto164', 'Hogar', 457.19, 98, 'Proveedor1', '2023-12-10', 'Almacén C')
# (165, 'Objeto165', 'Electrónica', 155.51, 2, 'Proveedor2', '2023-04-07', 'Almacén A')
# (166, 'Producto166', 'Jardín', 431.82, 37, 'Proveedor2', '2023-03-22', 'Almacén A')
# (167, 'Objeto167', 'Jardín', 269.95, 68, 'Proveedor3', '2023-08-07', 'Almacén A')
# (168, 'Artículo168', 'Moda', 129.34, 14, 'Proveedor2', '2023-03-18', 'Almacén A')
# (169, 'Artículo169', 'Moda', 111.26, 48, 'Proveedor3', '2023-12-04', 'Almacén B')
# (170, 'Artículo170', 'Deportes', 240.52, 3, 'Proveedor3', '2023-07-07', 'Almacén C')
# (171, 'Artículo171', 'Jardín', 437.05, 51, 'Proveedor3', '2023-02-24', 'Almacén B')
# (172, 'Objeto172', 'Hogar', 384.42, 59, 'Proveedor1', '2023-03-13', 'Almacén A')
# (173, 'Artículo173', 'Electrónica', 498.24, 46, 'Proveedor2', '2023-07-22', 'Almacén A')
# (174, 'Producto174', 'Jardín', 260.34, 27, 'Proveedor1', '2023-07-01', 'Almacén C')
# (175, 'Artículo175', 'Electrónica', 461.01, 96, 'Proveedor3', '2023-09-06', 'Almacén C')
# (176, 'Objeto176', 'Deportes', 184, 52, 'Proveedor1', '2023-01-14', 'Almacén A')
# (177, 'Artículo177', 'Deportes', 453.21, 99, 'Proveedor1', '2023-11-27', 'Almacén A')
# (178, 'Objeto178', 'Moda', 103.05, 50, 'Proveedor3', '2023-05-26', 'Almacén C')
# (179, 'Objeto179', 'Electrónica', 262.32, 87, 'Proveedor3', '2023-04-23', 'Almacén B')
# (180, 'Artículo180', 'Deportes', 78.19, 90, 'Proveedor3', '2023-03-09', 'Almacén B')
# (181, 'Producto181', 'Hogar', 406.79, 66, 'Proveedor3', '2023-02-22', 'Almacén B')
# (182, 'Objeto182', 'Jardín', 182.5, 73, 'Proveedor1', '2023-11-26', 'Almacén A')
# (183, 'Objeto183', 'Jardín', 17.64, 64, 'Proveedor3', '2023-08-10', 'Almacén A')
# (184, 'Producto184', 'Jardín', 38.52, 5, 'Proveedor1', '2023-05-15', 'Almacén A')
# (185, 'Objeto185', 'Hogar', 204.53, 74, 'Proveedor2', '2023-02-21', 'Almacén B')
# (186, 'Objeto186', 'Moda', 119.57, 4, 'Proveedor1', '2023-03-03', 'Almacén C')
# (187, 'Producto187', 'Electrónica', 493.26, 21, 'Proveedor2', '2023-01-13', 'Almacén B')
# (188, 'Objeto188', 'Jardín', 33.26, 83, 'Proveedor1', '2023-02-26', 'Almacén C')
# (189, 'Objeto189', 'Hogar', 372.53, 35, 'Proveedor1', '2023-01-07', 'Almacén C')
# (190, 'Producto190', 'Jardín', 30.19, 64, 'Proveedor3', '2023-12-10', 'Almacén B')
# (191, 'Objeto191', 'Hogar', 411.2, 21, 'Proveedor2', '2023-03-02', 'Almacén A')
# (192, 'Objeto192', 'Electrónica', 168.29, 15, 'Proveedor3', '2023-05-06', 'Almacén C')
# (193, 'Objeto193', 'Deportes', 384.6, 28, 'Proveedor1', '2023-07-14', 'Almacén C')
# (194, 'Producto194', 'Deportes', 120.02, 41, 'Proveedor1', '2023-04-24', 'Almacén C')
# (195, 'Objeto195', 'Moda', 466.57, 55, 'Proveedor2', '2023-01-06', 'Almacén C')
# (196, 'Objeto196', 'Electrónica', 240.9, 64, 'Proveedor2', '2023-07-14', 'Almacén C')
# (197, 'Objeto197', 'Jardín', 23.39, 91, 'Proveedor1', '2023-07-16', 'Almacén B')
# (198, 'Objeto198', 'Hogar', 203.79, 12, 'Proveedor3', '2023-03-19', 'Almacén C')
# (199, 'Objeto199', 'Moda', 176.05, 11, 'Proveedor3', '2023-06-21', 'Almacén C')
# (200, 'Objeto200', 'Jardín', 351.31, 16, 'Proveedor3', '2023-05-04', 'Almacén B')
# (201, 'Producto201', 'Deportes', 33.8, 56, 'Proveedor1', '2023-10-03', 'Almacén C')
# (202, 'Objeto202', 'Deportes', 262.4, 27, 'Proveedor3', '2023-11-13', 'Almacén C')
# (203, 'Producto203', 'Hogar', 320.37, 96, 'Proveedor1', '2023-07-27', 'Almacén B')
# (204, 'Artículo204', 'Electrónica', 231.9, 1, 'Proveedor3', '2023-12-21', 'Almacén C')
# (205, 'Producto205', 'Deportes', 218.79, 35, 'Proveedor3', '2023-01-10', 'Almacén A')
# (206, 'Objeto206', 'Moda', 239.83, 94, 'Proveedor3', '2023-10-27', 'Almacén B')
# (207, 'Producto207', 'Electrónica', 43.71, 76, 'Proveedor1', '2023-04-15', 'Almacén B')
# (208, 'Artículo208', 'Electrónica', 73.51, 19, 'Proveedor2', '2023-10-01', 'Almacén A')
# (209, 'Objeto209', 'Moda', 63.19, 7, 'Proveedor2', '2023-12-22', 'Almacén A')
# (210, 'Artículo210', 'Deportes', 10.89, 63, 'Proveedor1', '2023-08-05', 'Almacén B')
# (211, 'Artículo211', 'Electrónica', 461.81, 79, 'Proveedor2', '2023-03-16', 'Almacén B')
# (212, 'Producto212', 'Hogar', 110.07, 19, 'Proveedor3', '2023-12-02', 'Almacén B')
# (213, 'Artículo213', 'Moda', 98.7, 89, 'Proveedor2', '2023-08-20', 'Almacén C')
# (214, 'Objeto214', 'Moda', 472.32, 92, 'Proveedor2', '2023-05-13', 'Almacén A')
# (215, 'Objeto215', 'Hogar', 199.51, 53, 'Proveedor2', '2023-11-14', 'Almacén A')
# (216, 'Producto216', 'Deportes', 48.57, 68, 'Proveedor2', '2023-07-28', 'Almacén C')
# (217, 'Producto217', 'Electrónica', 168.57, 84, 'Proveedor3', '2023-05-23', 'Almacén A')
# (218, 'Objeto218', 'Jardín', 180.32, 88, 'Proveedor2', '2023-08-15', 'Almacén C')
# (219, 'Artículo219', 'Moda', 284.34, 81, 'Proveedor2', '2023-10-28', 'Almacén A')
# (220, 'Artículo220', 'Jardín', 95.76, 45, 'Proveedor1', '2023-04-03', 'Almacén B')
# (221, 'Objeto221', 'Hogar', 11.22, 54, 'Proveedor3', '2023-05-17', 'Almacén A')
# (222, 'Objeto222', 'Moda', 11.2, 7, 'Proveedor2', '2023-06-25', 'Almacén A')
# (223, 'Objeto223', 'Jardín', 367.15, 92, 'Proveedor3', '2023-11-19', 'Almacén B')
# (224, 'Artículo224', 'Hogar', 52.03, 14, 'Proveedor2', '2023-09-12', 'Almacén B')
# (225, 'Objeto225', 'Hogar', 78.38, 17, 'Proveedor3', '2023-07-07', 'Almacén C')
# (226, 'Objeto226', 'Moda', 227.2, 64, 'Proveedor3', '2023-06-12', 'Almacén B')
# (227, 'Objeto227', 'Electrónica', 389.79, 53, 'Proveedor2', '2023-02-06', 'Almacén B')
# (228, 'Artículo228', 'Hogar', 67.03, 46, 'Proveedor1', '2023-08-10', 'Almacén C')
# (229, 'Artículo229', 'Moda', 299.63, 9, 'Proveedor1', '2023-04-07', 'Almacén B')
# (230, 'Artículo230', 'Jardín', 351.6, 48, 'Proveedor2', '2023-05-20', 'Almacén A')
# (231, 'Objeto231', 'Jardín', 384.91, 14, 'Proveedor3', '2023-07-01', 'Almacén A')
# (232, 'Artículo232', 'Moda', 26.86, 68, 'Proveedor2', '2023-11-24', 'Almacén B')
# (233, 'Artículo233', 'Jardín', 259.16, 30, 'Proveedor1', '2023-08-02', 'Almacén A')
# (234, 'Objeto234', 'Jardín', 311.99, 27, 'Proveedor2', '2023-02-14', 'Almacén B')
# (235, 'Producto235', 'Hogar', 190.64, 16, 'Proveedor3', '2023-06-20', 'Almacén C')
# (236, 'Objeto236', 'Deportes', 332.11, 13, 'Proveedor1', '2023-08-28', 'Almacén B')
# (237, 'Objeto237', 'Moda', 306.11, 65, 'Proveedor3', '2023-12-21', 'Almacén A')
# (238, 'Producto238', 'Electrónica', 190.79, 16, 'Proveedor2', '2023-11-18', 'Almacén C')
# (239, 'Objeto239', 'Jardín', 170.96, 4, 'Proveedor1', '2023-08-10', 'Almacén C')
# (240, 'Producto240', 'Electrónica', 294.19, 71, 'Proveedor1', '2023-11-28', 'Almacén A')
# (241, 'Producto241', 'Hogar', 117.71, 99, 'Proveedor1', '2023-04-17', 'Almacén B')
# (242, 'Producto242', 'Hogar', 102.82, 73, 'Proveedor2', '2023-08-04', 'Almacén A')
# (243, 'Objeto243', 'Hogar', 184.49, 83, 'Proveedor1', '2023-11-25', 'Almacén C')
# (244, 'Artículo244', 'Jardín', 39.83, 6, 'Proveedor1', '2023-05-26', 'Almacén C')
# (245, 'Artículo245', 'Hogar', 318.38, 86, 'Proveedor3', '2023-10-08', 'Almacén B')
# (246, 'Producto246', 'Electrónica', 119.79, 43, 'Proveedor3', '2023-07-15', 'Almacén B')
# (247, 'Objeto247', 'Jardín', 173.08, 53, 'Proveedor2', '2023-11-14', 'Almacén B')
# (248, 'Objeto248', 'Hogar', 127.42, 15, 'Proveedor3', '2023-02-09', 'Almacén A')
# (249, 'Artículo249', 'Jardín', 185.22, 77, 'Proveedor2', '2023-10-22', 'Almacén B')
# (250, 'Producto250', 'Moda', 320.03, 26, 'Proveedor2', '2023-08-07', 'Almacén A')
# (251, 'Artículo251', 'Electrónica', 27.8, 17, 'Proveedor3', '2023-05-17', 'Almacén A')
# (252, 'Artículo252', 'Electrónica', 250.38, 55, 'Proveedor3', '2023-04-25', 'Almacén A')
# (253, 'Objeto253', 'Deportes', 278.51, 44, 'Proveedor3', '2023-05-16', 'Almacén A')
# (254, 'Producto254', 'Jardín', 328.27, 30, 'Proveedor1', '2023-08-13', 'Almacén A')
# (255, 'Objeto255', 'Moda', 13.79, 67, 'Proveedor3', '2023-05-20', 'Almacén C')
# (256, 'Artículo256', 'Deportes', 10.24, 81, 'Proveedor1', '2023-07-12', 'Almacén A')
# (257, 'Objeto257', 'Moda', 239.41, 40, 'Proveedor2', '2023-01-04', 'Almacén C')
# (258, 'Objeto258', 'Moda', 52.33, 88, 'Proveedor1', '2023-07-20', 'Almacén B')
# (259, 'Artículo259', 'Deportes', 472.82, 64, 'Proveedor1', '2023-04-09', 'Almacén C')
# (260, 'Objeto260', 'Hogar', 126.73, 85, 'Proveedor3', '2023-05-24', 'Almacén A')
# (261, 'Producto261', 'Hogar', 454.63, 39, 'Proveedor3', '2023-10-16', 'Almacén B')
# (262, 'Producto262', 'Jardín', 87.59, 72, 'Proveedor1', '2023-08-12', 'Almacén A')
# (263, 'Objeto263', 'Jardín', 32.39, 38, 'Proveedor1', '2023-07-04', 'Almacén C')
# (264, 'Artículo264', 'Hogar', 418.91, 20, 'Proveedor3', '2023-11-27', 'Almacén A')
# (265, 'Artículo265', 'Electrónica', 310.78, 65, 'Proveedor3', '2023-09-04', 'Almacén A')
# (266, 'Producto266', 'Jardín', 65.54, 16, 'Proveedor3', '2023-10-17', 'Almacén B')
# (267, 'Artículo267', 'Hogar', 325.39, 25, 'Proveedor3', '2023-04-05', 'Almacén B')
# (268, 'Artículo268', 'Deportes', 73.71, 5, 'Proveedor2', '2023-01-20', 'Almacén B')
# (269, 'Objeto269', 'Moda', 17.62, 100, 'Proveedor2', '2023-07-06', 'Almacén A')
# (270, 'Producto270', 'Deportes', 181.84, 16, 'Proveedor3', '2023-06-09', 'Almacén C')
# (271, 'Producto271', 'Moda', 336.94, 61, 'Proveedor2', '2023-04-26', 'Almacén B')
# (272, 'Objeto272', 'Deportes', 321.6, 57, 'Proveedor3', '2023-03-28', 'Almacén A')
# (273, 'Artículo273', 'Moda', 154.13, 34, 'Proveedor3', '2023-07-13', 'Almacén A')
# (274, 'Producto274', 'Moda', 161.09, 54, 'Proveedor3', '2023-09-25', 'Almacén C')
# (275, 'Artículo275', 'Jardín', 178.39, 71, 'Proveedor3', '2023-08-28', 'Almacén C')
# (276, 'Artículo276', 'Electrónica', 211.41, 76, 'Proveedor2', '2023-06-11', 'Almacén B')
# (277, 'Objeto277', 'Hogar', 153.27, 79, 'Proveedor2', '2023-12-07', 'Almacén B')
# (278, 'Producto278', 'Moda', 393.65, 87, 'Proveedor2', '2023-01-02', 'Almacén B')
# (279, 'Objeto279', 'Hogar', 311.75, 58, 'Proveedor3', '2023-04-15', 'Almacén A')
# (280, 'Artículo280', 'Deportes', 412.64, 34, 'Proveedor3', '2023-12-01', 'Almacén B')
# (281, 'Producto281', 'Deportes', 437.01, 43, 'Proveedor1', '2023-07-17', 'Almacén C')
# (282, 'Artículo282', 'Hogar', 428.51, 24, 'Proveedor1', '2023-07-03', 'Almacén A')
# (283, 'Objeto283', 'Hogar', 277.84, 86, 'Proveedor1', '2023-03-22', 'Almacén B')
# (284, 'Artículo284', 'Jardín', 229.57, 13, 'Proveedor2', '2023-12-14', 'Almacén A')
# (285, 'Objeto285', 'Hogar', 38.24, 72, 'Proveedor3', '2023-06-10', 'Almacén C')
# (286, 'Artículo286', 'Hogar', 129.87, 65, 'Proveedor2', '2023-11-06', 'Almacén C')
# (287, 'Artículo287', 'Jardín', 469.65, 14, 'Proveedor1', '2023-05-22', 'Almacén B')
# (288, 'Producto288', 'Deportes', 255.86, 77, 'Proveedor3', '2023-04-27', 'Almacén B')
# (289, 'Objeto289', 'Hogar', 236.39, 5, 'Proveedor3', '2023-10-22', 'Almacén C')
# (290, 'Objeto290', 'Moda', 473.54, 76, 'Proveedor3', '2023-05-19', 'Almacén C')
# (291, 'Artículo291', 'Moda', 365.84, 23, 'Proveedor3', '2023-09-04', 'Almacén A')
# (292, 'Artículo292', 'Electrónica', 308.18, 25, 'Proveedor3', '2023-01-26', 'Almacén B')
# (293, 'Artículo293', 'Electrónica', 180.24, 26, 'Proveedor1', '2023-05-27', 'Almacén C')
# (294, 'Producto294', 'Moda', 497.72, 33, 'Proveedor3', '2023-07-19', 'Almacén C')
# (295, 'Producto295', 'Hogar', 158.2, 71, 'Proveedor3', '2023-11-04', 'Almacén B')
# (296, 'Objeto296', 'Jardín', 307.89, 66, 'Proveedor3', '2023-06-21', 'Almacén B')
# (297, 'Objeto297', 'Hogar', 302.01, 75, 'Proveedor2', '2023-09-16', 'Almacén B')
# (298, 'Artículo298', 'Electrónica', 77.11, 59, 'Proveedor1', '2023-10-21', 'Almacén B')
# (299, 'Producto299', 'Deportes', 321.36, 72, 'Proveedor1', '2023-12-21', 'Almacén C')
# (300, 'Artículo300', 'Deportes', 398.47, 57, 'Proveedor1', '2023-10-16', 'Almacén B')
# (301, 'Artículo301', 'Moda', 87.78, 23, 'Proveedor2', '2023-01-11', 'Almacén B')
# (302, 'Artículo302', 'Hogar', 368.33, 86, 'Proveedor1', '2023-02-23', 'Almacén C')
# (303, 'Objeto303', 'Moda', 385.86, 25, 'Proveedor1', '2023-07-28', 'Almacén C')
# (304, 'Producto304', 'Deportes', 195.23, 27, 'Proveedor2', '2023-12-19', 'Almacén C')
# (305, 'Producto305', 'Jardín', 305.61, 47, 'Proveedor1', '2023-02-23', 'Almacén A')
# (306, 'Objeto306', 'Electrónica', 190.58, 74, 'Proveedor3', '2023-08-10', 'Almacén A')
# (307, 'Producto307', 'Jardín', 70.29, 49, 'Proveedor3', '2023-07-16', 'Almacén C')
# (308, 'Artículo308', 'Electrónica', 115.78, 43, 'Proveedor1', '2023-06-17', 'Almacén B')
# (309, 'Objeto309', 'Moda', 203.51, 60, 'Proveedor1', '2023-07-16', 'Almacén C')
# (310, 'Producto310', 'Deportes', 119.01, 48, 'Proveedor1', '2023-02-06', 'Almacén B')
# (311, 'Objeto311', 'Moda', 281.58, 81, 'Proveedor1', '2023-02-02', 'Almacén C')
# (312, 'Artículo312', 'Jardín', 352.66, 16, 'Proveedor3', '2023-02-10', 'Almacén A')
# (313, 'Objeto313', 'Electrónica', 348.7, 7, 'Proveedor1', '2023-09-14', 'Almacén A')
# (314, 'Producto314', 'Jardín', 37.22, 26, 'Proveedor2', '2023-12-01', 'Almacén A')
# (315, 'Artículo315', 'Electrónica', 76.46, 51, 'Proveedor3', '2023-08-05', 'Almacén B')
# (316, 'Objeto316', 'Moda', 158.86, 67, 'Proveedor1', '2023-02-25', 'Almacén A')
# (317, 'Producto317', 'Jardín', 215.35, 5, 'Proveedor3', '2023-11-25', 'Almacén B')
# (318, 'Producto318', 'Hogar', 41.56, 5, 'Proveedor3', '2023-06-16', 'Almacén C')
# (319, 'Producto319', 'Electrónica', 353.24, 68, 'Proveedor3', '2023-05-11', 'Almacén C')
# (320, 'Artículo320', 'Moda', 373.87, 37, 'Proveedor2', '2023-10-28', 'Almacén A')
# (321, 'Artículo321', 'Moda', 59.73, 30, 'Proveedor3', '2023-07-20', 'Almacén C')
# (322, 'Producto322', 'Hogar', 180.53, 63, 'Proveedor1', '2023-03-16', 'Almacén C')
# (323, 'Objeto323', 'Electrónica', 162.77, 43, 'Proveedor3', '2023-12-15', 'Almacén A')
# (324, 'Objeto324', 'Moda', 13.68, 17, 'Proveedor3', '2023-10-22', 'Almacén B')
# (325, 'Objeto325', 'Electrónica', 482.86, 18, 'Proveedor1', '2023-07-28', 'Almacén B')
# (326, 'Artículo326', 'Electrónica', 118.68, 29, 'Proveedor1', '2023-07-21', 'Almacén A')
# (327, 'Objeto327', 'Deportes', 225.18, 54, 'Proveedor1', '2023-07-16', 'Almacén A')
# (328, 'Objeto328', 'Electrónica', 165.3, 26, 'Proveedor3', '2023-10-19', 'Almacén C')
# (329, 'Producto329', 'Deportes', 51.61, 11, 'Proveedor3', '2023-07-23', 'Almacén B')
# (330, 'Producto330', 'Moda', 425.25, 73, 'Proveedor2', '2023-10-12', 'Almacén C')
# (331, 'Producto331', 'Electrónica', 228.41, 57, 'Proveedor3', '2023-09-26', 'Almacén A')
# (332, 'Objeto332', 'Moda', 76.84, 33, 'Proveedor3', '2023-11-20', 'Almacén A')
# (333, 'Objeto333', 'Deportes', 489.02, 4, 'Proveedor1', '2023-03-14', 'Almacén A')
# (334, 'Objeto334', 'Hogar', 21.55, 48, 'Proveedor3', '2023-08-13', 'Almacén A')
# (335, 'Producto335', 'Moda', 213.89, 68, 'Proveedor2', '2023-04-16', 'Almacén A')
# (336, 'Objeto336', 'Moda', 213.5, 45, 'Proveedor1', '2023-10-13', 'Almacén B')
# (337, 'Producto337', 'Moda', 42.57, 75, 'Proveedor2', '2023-10-01', 'Almacén A')
# (338, 'Objeto338', 'Deportes', 51.74, 3, 'Proveedor1', '2023-09-08', 'Almacén C')
# (339, 'Producto339', 'Deportes', 171.65, 42, 'Proveedor1', '2023-08-18', 'Almacén C')
# (340, 'Artículo340', 'Moda', 181.62, 4, 'Proveedor1', '2023-01-07', 'Almacén C')
# (341, 'Artículo341', 'Deportes', 272.45, 62, 'Proveedor3', '2023-01-01', 'Almacén C')
# (342, 'Artículo342', 'Jardín', 304.69, 70, 'Proveedor2', '2023-08-10', 'Almacén A')
# (343, 'Artículo343', 'Deportes', 293.05, 7, 'Proveedor3', '2023-08-21', 'Almacén B')
# (344, 'Artículo344', 'Hogar', 120.17, 30, 'Proveedor3', '2023-11-19', 'Almacén A')
# (345, 'Producto345', 'Electrónica', 152.11, 7, 'Proveedor2', '2023-11-20', 'Almacén A')
# (346, 'Objeto346', 'Deportes', 479.38, 54, 'Proveedor1', '2023-03-05', 'Almacén A')
# (347, 'Producto347', 'Jardín', 487.91, 83, 'Proveedor1', '2023-06-16', 'Almacén B')
# (348, 'Artículo348', 'Electrónica', 476.22, 54, 'Proveedor3', '2023-08-20', 'Almacén B')
# (349, 'Objeto349', 'Jardín', 323.32, 62, 'Proveedor3', '2023-06-16', 'Almacén C')
# (350, 'Artículo350', 'Deportes', 371.62, 67, 'Proveedor3', '2023-07-07', 'Almacén B')
# (351, 'Objeto351', 'Jardín', 25.55, 73, 'Proveedor1', '2023-06-09', 'Almacén C')
# (352, 'Producto352', 'Deportes', 184.79, 90, 'Proveedor3', '2023-09-23', 'Almacén B')
# (353, 'Artículo353', 'Hogar', 14.49, 34, 'Proveedor2', '2023-08-21', 'Almacén A')
# (354, 'Producto354', 'Jardín', 425.7, 90, 'Proveedor1', '2023-01-15', 'Almacén C')
# (355, 'Objeto355', 'Jardín', 417.82, 49, 'Proveedor1', '2023-03-24', 'Almacén C')
# (356, 'Artículo356', 'Moda', 54.95, 50, 'Proveedor2', '2023-04-06', 'Almacén C')
# (357, 'Artículo357', 'Deportes', 67.54, 2, 'Proveedor1', '2023-12-03', 'Almacén B')
# (358, 'Producto358', 'Hogar', 107.54, 17, 'Proveedor1', '2023-06-06', 'Almacén C')
# (359, 'Producto359', 'Deportes', 496.22, 46, 'Proveedor2', '2023-11-15', 'Almacén A')
# (360, 'Producto360', 'Hogar', 320.23, 74, 'Proveedor1', '2023-12-03', 'Almacén A')
# (361, 'Producto361', 'Deportes', 286.32, 33, 'Proveedor2', '2023-07-23', 'Almacén B')
# (362, 'Objeto362', 'Hogar', 227.6, 30, 'Proveedor3', '2023-02-19', 'Almacén A')
# (363, 'Artículo363', 'Jardín', 203.1, 43, 'Proveedor3', '2023-01-05', 'Almacén B')
# (364, 'Objeto364', 'Hogar', 176.71, 78, 'Proveedor3', '2023-11-21', 'Almacén B')
# (365, 'Producto365', 'Deportes', 359.91, 45, 'Proveedor1', '2023-01-20', 'Almacén C')
# (366, 'Artículo366', 'Electrónica', 71.62, 42, 'Proveedor1', '2023-09-10', 'Almacén B')
# (367, 'Producto367', 'Moda', 369.83, 78, 'Proveedor3', '2023-06-28', 'Almacén C')
# (368, 'Objeto368', 'Electrónica', 197.77, 46, 'Proveedor2', '2023-11-15', 'Almacén C')
# (369, 'Producto369', 'Jardín', 312.59, 40, 'Proveedor3', '2023-06-03', 'Almacén C')
# (370, 'Producto370', 'Moda', 19.68, 99, 'Proveedor2', '2023-01-09', 'Almacén C')
# (371, 'Objeto371', 'Jardín', 497.64, 87, 'Proveedor2', '2023-06-22', 'Almacén B')
# (372, 'Producto372', 'Electrónica', 41.49, 30, 'Proveedor2', '2023-07-19', 'Almacén A')
# (373, 'Artículo373', 'Deportes', 19.68, 76, 'Proveedor1', '2023-03-08', 'Almacén A')
# (374, 'Artículo374', 'Electrónica', 55.72, 40, 'Proveedor1', '2023-09-23', 'Almacén A')
# (375, 'Producto375', 'Deportes', 363.57, 100, 'Proveedor1', '2023-03-17', 'Almacén C')
# (376, 'Artículo376', 'Moda', 190.73, 29, 'Proveedor1', '2023-01-28', 'Almacén C')
# (377, 'Objeto377', 'Moda', 419.3, 37, 'Proveedor2', '2023-09-17', 'Almacén A')
# (378, 'Artículo378', 'Hogar', 449.22, 34, 'Proveedor2', '2023-08-14', 'Almacén C')
# (379, 'Artículo379', 'Jardín', 52.51, 70, 'Proveedor1', '2023-04-26', 'Almacén C')
# (380, 'Producto380', 'Moda', 378.91, 19, 'Proveedor3', '2023-04-12', 'Almacén C')
# (381, 'Artículo381', 'Jardín', 316.16, 11, 'Proveedor3', '2023-08-21', 'Almacén B')
# (382, 'Objeto382', 'Moda', 228.7, 89, 'Proveedor1', '2023-07-28', 'Almacén A')
# (383, 'Objeto383', 'Hogar', 89.45, 32, 'Proveedor1', '2023-08-28', 'Almacén C')
# (384, 'Artículo384', 'Jardín', 147.91, 97, 'Proveedor3', '2023-06-03', 'Almacén A')
# (385, 'Objeto385', 'Moda', 283.97, 67, 'Proveedor3', '2023-02-16', 'Almacén A')
# (386, 'Producto386', 'Jardín', 405.71, 83, 'Proveedor3', '2023-05-21', 'Almacén A')
# (387, 'Artículo387', 'Electrónica', 211.51, 29, 'Proveedor2', '2023-10-20', 'Almacén A')
# (388, 'Objeto388', 'Jardín', 398.81, 95, 'Proveedor2', '2023-08-15', 'Almacén A')
# (389, 'Artículo389', 'Moda', 452.93, 26, 'Proveedor2', '2023-09-13', 'Almacén C')
# (390, 'Artículo390', 'Deportes', 181.84, 25, 'Proveedor3', '2023-10-05', 'Almacén C')
# (391, 'Artículo391', 'Moda', 426.96, 50, 'Proveedor3', '2023-12-15', 'Almacén A')
# (392, 'Producto392', 'Moda', 486.6, 90, 'Proveedor2', '2023-04-07', 'Almacén C')
# (393, 'Artículo393', 'Jardín', 223.29, 65, 'Proveedor1', '2023-03-07', 'Almacén B')
# (394, 'Producto394', 'Electrónica', 157.55, 2, 'Proveedor2', '2023-10-14', 'Almacén B')
# (395, 'Objeto395', 'Hogar', 158.66, 17, 'Proveedor3', '2023-09-02', 'Almacén A')
# (396, 'Objeto396', 'Hogar', 409.86, 63, 'Proveedor2', '2023-09-12', 'Almacén C')
# (397, 'Objeto397', 'Deportes', 374.54, 100, 'Proveedor3', '2023-11-01', 'Almacén C')
# (398, 'Artículo398', 'Moda', 458.9, 10, 'Proveedor3', '2023-10-18', 'Almacén C')
# (399, 'Artículo399', 'Deportes', 56.45, 51, 'Proveedor1', '2023-06-22', 'Almacén A')
# (400, 'Producto400', 'Moda', 191.67, 63, 'Proveedor3', '2023-06-22', 'Almacén C')
# (401, 'Objeto401', 'Jardín', 128.42, 44, 'Proveedor3', '2023-04-10', 'Almacén B')
# (402, 'Artículo402', 'Deportes', 158.02, 76, 'Proveedor2', '2023-05-07', 'Almacén A')
# (403, 'Objeto403', 'Deportes', 211.65, 59, 'Proveedor1', '2023-11-15', 'Almacén C')
# (404, 'Objeto404', 'Deportes', 371.16, 24, 'Proveedor2', '2023-04-02', 'Almacén B')
# (405, 'Producto405', 'Electrónica', 62.77, 57, 'Proveedor2', '2023-05-18', 'Almacén B')
# (406, 'Producto406', 'Electrónica', 49.98, 22, 'Proveedor2', '2023-05-28', 'Almacén A')
# (407, 'Objeto407', 'Moda', 278.29, 65, 'Proveedor1', '2023-01-04', 'Almacén A')
# (408, 'Artículo408', 'Electrónica', 153.58, 2, 'Proveedor2', '2023-08-24', 'Almacén A')
# (409, 'Objeto409', 'Moda', 387.51, 97, 'Proveedor3', '2023-04-06', 'Almacén B')
# (410, 'Objeto410', 'Hogar', 99.35, 72, 'Proveedor1', '2023-07-15', 'Almacén B')
# (411, 'Producto411', 'Moda', 188.59, 96, 'Proveedor1', '2023-02-14', 'Almacén C')
# (412, 'Objeto412', 'Moda', 308.95, 66, 'Proveedor1', '2023-09-04', 'Almacén A')
# (413, 'Objeto413', 'Deportes', 138.42, 6, 'Proveedor2', '2023-05-17', 'Almacén B')
# (414, 'Objeto414', 'Electrónica', 188.22, 24, 'Proveedor2', '2023-08-17', 'Almacén A')
# (415, 'Producto415', 'Moda', 237.87, 49, 'Proveedor2', '2023-08-24', 'Almacén C')
# (416, 'Objeto416', 'Hogar', 203.22, 6, 'Proveedor2', '2023-07-16', 'Almacén B')
# (417, 'Artículo417', 'Hogar', 347.56, 51, 'Proveedor2', '2023-01-02', 'Almacén C')
# (418, 'Producto418', 'Electrónica', 455.94, 78, 'Proveedor1', '2023-06-15', 'Almacén B')
# (419, 'Producto419', 'Jardín', 23.75, 97, 'Proveedor1', '2023-09-22', 'Almacén C')
# (420, 'Producto420', 'Deportes', 172.72, 62, 'Proveedor1', '2023-11-13', 'Almacén C')
# (421, 'Producto421', 'Deportes', 241.27, 81, 'Proveedor2', '2023-03-16', 'Almacén A')
# (422, 'Objeto422', 'Electrónica', 151.31, 55, 'Proveedor1', '2023-02-19', 'Almacén C')
# (423, 'Producto423', 'Hogar', 162.83, 76, 'Proveedor3', '2023-07-23', 'Almacén B')
# (424, 'Artículo424', 'Moda', 453.11, 16, 'Proveedor2', '2023-07-26', 'Almacén A')
# (425, 'Producto425', 'Deportes', 138.36, 30, 'Proveedor1', '2023-08-11', 'Almacén A')
# (426, 'Producto426', 'Deportes', 341.49, 4, 'Proveedor3', '2023-08-05', 'Almacén B')
# (427, 'Objeto427', 'Jardín', 294.51, 60, 'Proveedor2', '2023-06-18', 'Almacén A')
# (428, 'Producto428', 'Jardín', 22.53, 58, 'Proveedor2', '2023-09-16', 'Almacén B')
# (429, 'Artículo429', 'Moda', 405.17, 36, 'Proveedor2', '2023-10-20', 'Almacén C')
# (430, 'Producto430', 'Hogar', 268.85, 7, 'Proveedor3', '2023-06-18', 'Almacén A')
# (431, 'Producto431', 'Jardín', 354.32, 16, 'Proveedor2', '2023-10-02', 'Almacén B')
# (432, 'Producto432', 'Jardín', 324.93, 47, 'Proveedor3', '2023-10-16', 'Almacén A')
# (433, 'Producto433', 'Deportes', 415.33, 16, 'Proveedor2', '2023-06-02', 'Almacén B')
# (434, 'Artículo434', 'Jardín', 308.39, 39, 'Proveedor1', '2023-12-15', 'Almacén B')
# (435, 'Objeto435', 'Jardín', 298.9, 38, 'Proveedor2', '2023-09-03', 'Almacén A')
# (436, 'Artículo436', 'Deportes', 201.38, 98, 'Proveedor1', '2023-03-02', 'Almacén A')
# (437, 'Artículo437', 'Moda', 296.18, 28, 'Proveedor2', '2023-12-19', 'Almacén A')
# (438, 'Artículo438', 'Moda', 247.63, 18, 'Proveedor3', '2023-05-12', 'Almacén B')
# (439, 'Producto439', 'Deportes', 472.46, 98, 'Proveedor3', '2023-06-08', 'Almacén A')
# (440, 'Objeto440', 'Electrónica', 370.82, 79, 'Proveedor1', '2023-01-09', 'Almacén B')
# (441, 'Artículo441', 'Hogar', 246.48, 29, 'Proveedor1', '2023-01-26', 'Almacén A')
# (442, 'Artículo442', 'Moda', 443.94, 92, 'Proveedor1', '2023-02-22', 'Almacén B')
# (443, 'Producto443', 'Electrónica', 447.7, 67, 'Proveedor3', '2023-07-01', 'Almacén C')
# (444, 'Objeto444', 'Hogar', 89.09, 86, 'Proveedor3', '2023-01-12', 'Almacén A')
# (445, 'Artículo445', 'Hogar', 442.15, 58, 'Proveedor1', '2023-05-08', 'Almacén B')
# (446, 'Artículo446', 'Hogar', 227.96, 1, 'Proveedor1', '2023-05-15', 'Almacén A')
# (447, 'Producto447', 'Electrónica', 92.11, 16, 'Proveedor3', '2023-03-10', 'Almacén C')
# (448, 'Objeto448', 'Electrónica', 12.26, 42, 'Proveedor3', '2023-01-27', 'Almacén C')
# (449, 'Artículo449', 'Hogar', 358.91, 10, 'Proveedor3', '2023-11-28', 'Almacén A')
# (450, 'Producto450', 'Jardín', 105.18, 40, 'Proveedor1', '2023-11-10', 'Almacén B')
# (451, 'Producto451', 'Electrónica', 488.15, 66, 'Proveedor1', '2023-03-21', 'Almacén A')
# (452, 'Producto452', 'Moda', 364.09, 46, 'Proveedor1', '2023-10-05', 'Almacén C')
# (453, 'Artículo453', 'Electrónica', 60.75, 15, 'Proveedor2', '2023-06-21', 'Almacén C')
# (454, 'Objeto454', 'Hogar', 117.71, 44, 'Proveedor3', '2023-08-10', 'Almacén B')
# (455, 'Artículo455', 'Jardín', 459.07, 98, 'Proveedor2', '2023-11-04', 'Almacén C')
# (456, 'Artículo456', 'Hogar', 336.33, 33, 'Proveedor2', '2023-11-17', 'Almacén C')
# (457, 'Artículo457', 'Deportes', 427.3, 73, 'Proveedor2', '2023-04-15', 'Almacén A')
# (458, 'Producto458', 'Hogar', 117.15, 77, 'Proveedor1', '2023-01-17', 'Almacén C')
# (459, 'Artículo459', 'Deportes', 322.3, 42, 'Proveedor2', '2023-09-08', 'Almacén A')
# (460, 'Objeto460', 'Electrónica', 95.56, 51, 'Proveedor1', '2023-07-24', 'Almacén A')
# (461, 'Artículo461', 'Electrónica', 381.38, 94, 'Proveedor2', '2023-03-02', 'Almacén B')
# (462, 'Producto462', 'Deportes', 215, 24, 'Proveedor2', '2023-08-28', 'Almacén C')
# (463, 'Producto463', 'Jardín', 336.9, 76, 'Proveedor2', '2023-08-26', 'Almacén B')
# (464, 'Artículo464', 'Electrónica', 325.38, 92, 'Proveedor1', '2023-09-18', 'Almacén B')
# (465, 'Producto465', 'Jardín', 115.99, 70, 'Proveedor3', '2023-06-20', 'Almacén A')
# (466, 'Producto466', 'Hogar', 472.74, 81, 'Proveedor2', '2023-08-15', 'Almacén A')
# (467, 'Artículo467', 'Deportes', 201.95, 76, 'Proveedor2', '2023-02-24', 'Almacén B')
# (468, 'Producto468', 'Electrónica', 407.11, 86, 'Proveedor3', '2023-05-22', 'Almacén C')
# (469, 'Producto469', 'Hogar', 275.48, 73, 'Proveedor3', '2023-08-24', 'Almacén C')
# (470, 'Objeto470', 'Moda', 341.08, 46, 'Proveedor3', '2023-02-14', 'Almacén B')
# (471, 'Artículo471', 'Electrónica', 489.86, 40, 'Proveedor2', '2023-02-23', 'Almacén C')
# (472, 'Artículo472', 'Deportes', 24.18, 34, 'Proveedor2', '2023-09-15', 'Almacén B')
# (473, 'Objeto473', 'Moda', 111.8, 56, 'Proveedor3', '2023-05-23', 'Almacén C')
# (474, 'Producto474', 'Hogar', 262.94, 60, 'Proveedor3', '2023-04-25', 'Almacén B')
# (475, 'Producto475', 'Deportes', 235.69, 44, 'Proveedor2', '2023-03-27', 'Almacén A')
# (476, 'Artículo476', 'Deportes', 410.19, 28, 'Proveedor2', '2023-02-15', 'Almacén B')
# (477, 'Producto477', 'Electrónica', 44.17, 97, 'Proveedor1', '2023-04-28', 'Almacén B')
# (478, 'Producto478', 'Hogar', 47.39, 63, 'Proveedor1', '2023-07-20', 'Almacén B')
# (479, 'Objeto479', 'Deportes', 260.07, 62, 'Proveedor3', '2023-05-03', 'Almacén C')
# (480, 'Artículo480', 'Moda', 401.39, 76, 'Proveedor3', '2023-10-27', 'Almacén A')
# (481, 'Artículo481', 'Hogar', 351.09, 90, 'Proveedor1', '2023-12-15', 'Almacén C')
# (482, 'Objeto482', 'Electrónica', 135.11, 5, 'Proveedor2', '2023-09-11', 'Almacén B')
# (483, 'Objeto483', 'Moda', 497.86, 83, 'Proveedor3', '2023-09-19', 'Almacén C')
# (484, 'Artículo484', 'Hogar', 10.35, 75, 'Proveedor3', '2023-05-07', 'Almacén A')
# (485, 'Artículo485', 'Electrónica', 130.41, 74, 'Proveedor1', '2023-08-14', 'Almacén C')
# (486, 'Artículo486', 'Jardín', 251.32, 44, 'Proveedor2', '2023-01-17', 'Almacén C')
# (487, 'Objeto487', 'Moda', 313.66, 32, 'Proveedor2', '2023-01-19', 'Almacén C')
# (488, 'Artículo488', 'Jardín', 85.53, 58, 'Proveedor1', '2023-10-06', 'Almacén C')
# (489, 'Artículo489', 'Jardín', 20.99, 99, 'Proveedor3', '2023-04-22', 'Almacén C')
# (490, 'Artículo490', 'Hogar', 47.47, 79, 'Proveedor2', '2023-10-03', 'Almacén A')
# (491, 'Producto491', 'Deportes', 235.31, 9, 'Proveedor1', '2023-05-25', 'Almacén A')
# (492, 'Artículo492', 'Deportes', 478.13, 8, 'Proveedor2', '2023-01-26', 'Almacén A')
# (493, 'Producto493', 'Electrónica', 239.7, 53, 'Proveedor2', '2023-10-21', 'Almacén B')
# (494, 'Producto494', 'Electrónica', 311.85, 35, 'Proveedor2', '2023-07-24', 'Almacén C')
# (495, 'Artículo495', 'Hogar', 384.86, 44, 'Proveedor1', '2023-11-23', 'Almacén B')
# (496, 'Artículo496', 'Deportes', 109.81, 45, 'Proveedor2', '2023-01-02', 'Almacén A')
# (497, 'Producto497', 'Moda', 415.29, 34, 'Proveedor1', '2023-02-19', 'Almacén A')
# (498, 'Producto498', 'Hogar', 311.8, 45, 'Proveedor2', '2023-10-10', 'Almacén A')
# (499, 'Producto499', 'Deportes', 351.79, 72, 'Proveedor1', '2023-10-26', 'Almacén B')
# (500, 'Artículo500', 'Moda', 322.94, 81, 'Proveedor2', '2023-06-17', 'Almacén C')
# (501, 'Objeto501', 'Electrónica', 240.22, 82, 'Proveedor3', '2023-05-24', 'Almacén B')
# (502, 'Producto502', 'Hogar', 20.92, 12, 'Proveedor2', '2023-03-28', 'Almacén B')
# (503, 'Objeto503', 'Electrónica', 476.09, 8, 'Proveedor2', '2023-05-12', 'Almacén B')
# (504, 'Producto504', 'Deportes', 140.51, 3, 'Proveedor1', '2023-01-04', 'Almacén A')
# (505, 'Artículo505', 'Hogar', 198.37, 4, 'Proveedor1', '2023-08-10', 'Almacén C')
# (506, 'Objeto506', 'Deportes', 481.87, 43, 'Proveedor1', '2023-10-20', 'Almacén B')
# (507, 'Producto507', 'Moda', 326.44, 74, 'Proveedor2', '2023-10-15', 'Almacén C')
# (508, 'Artículo508', 'Hogar', 103.73, 99, 'Proveedor3', '2023-10-11', 'Almacén A')
# (509, 'Objeto509', 'Moda', 217.26, 18, 'Proveedor3', '2023-12-16', 'Almacén B')
# (510, 'Objeto510', 'Moda', 266.87, 56, 'Proveedor1', '2023-07-11', 'Almacén C')
# (511, 'Producto511', 'Jardín', 233.38, 26, 'Proveedor3', '2023-03-07', 'Almacén C')
# (512, 'Producto512', 'Jardín', 157.22, 20, 'Proveedor2', '2023-04-10', 'Almacén A')
# (513, 'Producto513', 'Jardín', 206.37, 5, 'Proveedor3', '2023-01-20', 'Almacén C')
# (514, 'Artículo514', 'Electrónica', 169.55, 3, 'Proveedor2', '2023-09-13', 'Almacén B')
# (515, 'Objeto515', 'Moda', 329.23, 50, 'Proveedor3', '2023-07-12', 'Almacén C')
# (516, 'Artículo516', 'Deportes', 190.47, 10, 'Proveedor1', '2023-08-07', 'Almacén C')
# (517, 'Artículo517', 'Moda', 106.46, 10, 'Proveedor1', '2023-02-12', 'Almacén C')
# (518, 'Producto518', 'Electrónica', 361.11, 61, 'Proveedor3', '2023-01-07', 'Almacén A')
# (519, 'Producto519', 'Jardín', 24.92, 98, 'Proveedor1', '2023-08-01', 'Almacén C')
# (520, 'Objeto520', 'Hogar', 294.95, 49, 'Proveedor2', '2023-11-18', 'Almacén A')
# (521, 'Artículo521', 'Hogar', 427.83, 78, 'Proveedor2', '2023-05-04', 'Almacén C')
# (522, 'Objeto522', 'Hogar', 186.45, 20, 'Proveedor2', '2023-03-11', 'Almacén C')
# (523, 'Artículo523', 'Jardín', 175.26, 84, 'Proveedor3', '2023-04-17', 'Almacén A')
# (524, 'Artículo524', 'Moda', 201.85, 43, 'Proveedor3', '2023-09-20', 'Almacén C')
# (525, 'Producto525', 'Jardín', 149.17, 24, 'Proveedor2', '2023-06-19', 'Almacén A')
# (526, 'Objeto526', 'Jardín', 396.28, 12, 'Proveedor3', '2023-12-23', 'Almacén C')
# (527, 'Artículo527', 'Deportes', 52.18, 61, 'Proveedor1', '2023-03-16', 'Almacén C')
# (528, 'Objeto528', 'Electrónica', 243.68, 89, 'Proveedor2', '2023-04-20', 'Almacén C')
# (529, 'Artículo529', 'Electrónica', 427.68, 5, 'Proveedor3', '2023-07-20', 'Almacén B')
# (530, 'Producto530', 'Jardín', 148.2, 72, 'Proveedor2', '2023-08-16', 'Almacén A')
# (531, 'Artículo531', 'Electrónica', 66.51, 79, 'Proveedor3', '2023-03-23', 'Almacén C')
# (532, 'Artículo532', 'Moda', 468.44, 12, 'Proveedor1', '2023-06-05', 'Almacén C')
# (533, 'Artículo533', 'Jardín', 448.97, 58, 'Proveedor2', '2023-05-04', 'Almacén B')
# (534, 'Artículo534', 'Deportes', 400.13, 8, 'Proveedor1', '2023-03-19', 'Almacén C')
# (535, 'Artículo535', 'Hogar', 407.61, 99, 'Proveedor3', '2023-06-02', 'Almacén C')
# (536, 'Producto536', 'Moda', 142.63, 40, 'Proveedor3', '2023-11-16', 'Almacén B')
# (537, 'Artículo537', 'Electrónica', 45.21, 16, 'Proveedor3', '2023-12-06', 'Almacén C')
# (538, 'Artículo538', 'Moda', 379.7, 4, 'Proveedor1', '2023-09-04', 'Almacén B')
# (539, 'Artículo539', 'Hogar', 248.25, 86, 'Proveedor1', '2023-09-21', 'Almacén C')
# (540, 'Objeto540', 'Electrónica', 476.15, 7, 'Proveedor2', '2023-09-23', 'Almacén B')
# (541, 'Producto541', 'Hogar', 421.5, 1, 'Proveedor3', '2023-10-15', 'Almacén C')
# (542, 'Producto542', 'Moda', 283.11, 91, 'Proveedor3', '2023-01-13', 'Almacén B')
# (543, 'Objeto543', 'Jardín', 47.31, 54, 'Proveedor3', '2023-10-02', 'Almacén A')
# (544, 'Artículo544', 'Moda', 26.83, 43, 'Proveedor2', '2023-10-01', 'Almacén C')
# (545, 'Objeto545', 'Moda', 50.79, 69, 'Proveedor3', '2023-06-23', 'Almacén A')
# (546, 'Objeto546', 'Electrónica', 425.67, 57, 'Proveedor1', '2023-08-20', 'Almacén C')
# (547, 'Objeto547', 'Deportes', 209.03, 59, 'Proveedor2', '2023-12-13', 'Almacén C')
# (548, 'Artículo548', 'Jardín', 71.13, 5, 'Proveedor1', '2023-09-28', 'Almacén A')
# (549, 'Artículo549', 'Hogar', 122.9, 18, 'Proveedor3', '2023-07-19', 'Almacén A')
# (550, 'Producto550', 'Moda', 57.98, 95, 'Proveedor2', '2023-06-28', 'Almacén A')
# (551, 'Artículo551', 'Electrónica', 378.12, 3, 'Proveedor1', '2023-04-19', 'Almacén B')
# (552, 'Objeto552', 'Deportes', 15.92, 63, 'Proveedor2', '2023-02-20', 'Almacén A')
# (553, 'Producto553', 'Moda', 65.81, 98, 'Proveedor1', '2023-06-28', 'Almacén B')
# (554, 'Objeto554', 'Hogar', 107.59, 19, 'Proveedor3', '2023-07-20', 'Almacén C')
# (555, 'Producto555', 'Deportes', 101.29, 79, 'Proveedor3', '2023-11-09', 'Almacén C')
# (556, 'Objeto556', 'Electrónica', 282.5, 40, 'Proveedor3', '2023-05-06', 'Almacén B')
# (557, 'Artículo557', 'Electrónica', 374.71, 100, 'Proveedor1', '2023-12-25', 'Almacén B')
# (558, 'Artículo558', 'Moda', 448.45, 88, 'Proveedor1', '2023-05-04', 'Almacén B')
# (559, 'Producto559', 'Jardín', 158.92, 24, 'Proveedor3', '2023-06-23', 'Almacén B')
# (560, 'Artículo560', 'Deportes', 37.12, 4, 'Proveedor3', '2023-02-26', 'Almacén C')
# (561, 'Producto561', 'Electrónica', 339.49, 30, 'Proveedor3', '2023-08-08', 'Almacén B')
# (562, 'Artículo562', 'Deportes', 434.14, 17, 'Proveedor1', '2023-08-26', 'Almacén A')
# (563, 'Objeto563', 'Jardín', 464.58, 78, 'Proveedor1', '2023-06-23', 'Almacén C')
# (564, 'Objeto564', 'Moda', 246.56, 19, 'Proveedor2', '2023-12-14', 'Almacén C')
# (565, 'Producto565', 'Hogar', 75.27, 19, 'Proveedor2', '2023-08-23', 'Almacén B')
# (566, 'Producto566', 'Deportes', 426.66, 63, 'Proveedor2', '2023-09-19', 'Almacén A')
# (567, 'Objeto567', 'Hogar', 62.74, 81, 'Proveedor2', '2023-02-14', 'Almacén C')
# (568, 'Artículo568', 'Deportes', 183.16, 22, 'Proveedor3', '2023-09-04', 'Almacén B')
# (569, 'Objeto569', 'Jardín', 165.52, 39, 'Proveedor2', '2023-04-25', 'Almacén A')
# (570, 'Artículo570', 'Deportes', 307.46, 12, 'Proveedor3', '2023-07-24', 'Almacén A')
# (571, 'Objeto571', 'Moda', 200.64, 47, 'Proveedor3', '2023-09-27', 'Almacén A')
# (572, 'Objeto572', 'Moda', 236.62, 29, 'Proveedor3', '2023-11-09', 'Almacén A')
# (573, 'Objeto573', 'Hogar', 456.95, 52, 'Proveedor3', '2023-03-08', 'Almacén A')
# (574, 'Artículo574', 'Moda', 483.05, 46, 'Proveedor2', '2023-11-23', 'Almacén C')
# (575, 'Producto575', 'Moda', 39.78, 32, 'Proveedor2', '2023-10-11', 'Almacén C')
# (576, 'Objeto576', 'Electrónica', 17.39, 54, 'Proveedor3', '2023-12-20', 'Almacén A')
# (577, 'Artículo577', 'Deportes', 33.41, 33, 'Proveedor3', '2023-06-04', 'Almacén C')
# ...
# (9815, 'Producto9815', 'Jardín', 104.9, 77, 'Proveedor3', '2023-07-26', 'Almacén A')
# (9816, 'Objeto9816', 'Electrónica', 322.68, 84, 'Proveedor1', '2023-10-26', 'Almacén C')
# (9817, 'Objeto9817', 'Jardín', 67.09, 99, 'Proveedor3', '2023-07-14', 'Almacén A')
# (9818, 'Objeto9818', 'Moda', 235.78, 12, 'Proveedor1', '2023-02-24', 'Almacén B')
# (9819, 'Artículo9819', 'Hogar', 117.25, 49, 'Proveedor3', '2023-09-21', 'Almacén A')
# (9820, 'Objeto9820', 'Jardín', 213.06, 51, 'Proveedor3', '2023-04-11', 'Almacén C')
# (9821, 'Artículo9821', 'Hogar', 218.48, 13, 'Proveedor2', '2023-09-09', 'Almacén B')
# (9822, 'Artículo9822', 'Jardín', 393.38, 22, 'Proveedor2', '2023-09-03', 'Almacén C')
# (9823, 'Objeto9823', 'Electrónica', 147.9, 47, 'Proveedor3', '2023-06-05', 'Almacén C')
# (9824, 'Producto9824', 'Hogar', 93.6, 74, 'Proveedor3', '2023-06-19', 'Almacén C')
# (9825, 'Artículo9825', 'Hogar', 130.34, 14, 'Proveedor2', '2023-03-13', 'Almacén C')
# (9826, 'Artículo9826', 'Deportes', 236.33, 64, 'Proveedor2', '2023-05-16', 'Almacén C')
# (9827, 'Artículo9827', 'Deportes', 441.26, 26, 'Proveedor3', '2023-01-22', 'Almacén C')
# (9828, 'Objeto9828', 'Hogar', 295.38, 43, 'Proveedor3', '2023-06-22', 'Almacén A')
# (9829, 'Artículo9829', 'Jardín', 329.01, 63, 'Proveedor2', '2023-01-17', 'Almacén C')
# (9830, 'Objeto9830', 'Deportes', 74.5, 51, 'Proveedor1', '2023-11-23', 'Almacén B')
# (9831, 'Producto9831', 'Moda', 283.63, 97, 'Proveedor1', '2023-05-12', 'Almacén C')
# (9832, 'Artículo9832', 'Moda', 107.04, 5, 'Proveedor1', '2023-02-19', 'Almacén C')
# (9833, 'Artículo9833', 'Moda', 482.94, 94, 'Proveedor3', '2023-02-13', 'Almacén B')
# (9834, 'Objeto9834', 'Hogar', 330.91, 5, 'Proveedor1', '2023-06-27', 'Almacén A')
# (9835, 'Artículo9835', 'Jardín', 264.7, 65, 'Proveedor2', '2023-04-07', 'Almacén B')
# (9836, 'Producto9836', 'Hogar', 262.51, 19, 'Proveedor2', '2023-01-04', 'Almacén A')
# (9837, 'Artículo9837', 'Hogar', 233.65, 20, 'Proveedor1', '2023-12-09', 'Almacén A')
# (9838, 'Objeto9838', 'Hogar', 430.46, 1, 'Proveedor3', '2023-07-17', 'Almacén A')
# (9839, 'Producto9839', 'Moda', 63.03, 31, 'Proveedor2', '2023-07-01', 'Almacén B')
# (9840, 'Objeto9840', 'Deportes', 333.05, 70, 'Proveedor2', '2023-07-27', 'Almacén A')
# (9841, 'Objeto9841', 'Jardín', 238.95, 91, 'Proveedor2', '2023-01-16', 'Almacén A')
# (9842, 'Producto9842', 'Jardín', 306.92, 59, 'Proveedor3', '2023-10-17', 'Almacén B')
# (9843, 'Producto9843', 'Electrónica', 324.89, 2, 'Proveedor1', '2023-03-14', 'Almacén A')
# (9844, 'Producto9844', 'Electrónica', 355.97, 80, 'Proveedor3', '2023-11-11', 'Almacén B')
# (9845, 'Artículo9845', 'Hogar', 39.29, 35, 'Proveedor3', '2023-11-09', 'Almacén B')
# (9846, 'Artículo9846', 'Electrónica', 426.49, 53, 'Proveedor2', '2023-05-09', 'Almacén B')
# (9847, 'Producto9847', 'Deportes', 464.33, 94, 'Proveedor2', '2023-08-08', 'Almacén B')
# (9848, 'Objeto9848', 'Deportes', 124.26, 73, 'Proveedor1', '2023-10-03', 'Almacén B')
# (9849, 'Artículo9849', 'Hogar', 450.05, 60, 'Proveedor2', '2023-07-05', 'Almacén C')
# (9850, 'Objeto9850', 'Deportes', 216.14, 20, 'Proveedor3', '2023-09-01', 'Almacén A')
# (9851, 'Producto9851', 'Hogar', 163.21, 53, 'Proveedor2', '2023-06-24', 'Almacén A')
# (9852, 'Objeto9852', 'Jardín', 373.19, 29, 'Proveedor1', '2023-04-23', 'Almacén A')
# (9853, 'Objeto9853', 'Hogar', 25.73, 4, 'Proveedor2', '2023-08-19', 'Almacén C')
# (9854, 'Objeto9854', 'Deportes', 359.31, 33, 'Proveedor1', '2023-04-01', 'Almacén C')
# (9855, 'Objeto9855', 'Jardín', 201.2, 10, 'Proveedor3', '2023-04-23', 'Almacén C')
# (9856, 'Artículo9856', 'Deportes', 458.04, 9, 'Proveedor3', '2023-03-26', 'Almacén C')
# (9857, 'Producto9857', 'Deportes', 402.53, 33, 'Proveedor2', '2023-10-13', 'Almacén B')
# (9858, 'Artículo9858', 'Electrónica', 78.85, 81, 'Proveedor3', '2023-08-04', 'Almacén B')
# (9859, 'Producto9859', 'Electrónica', 468.76, 76, 'Proveedor1', '2023-01-06', 'Almacén B')
# (9860, 'Artículo9860', 'Hogar', 185.67, 3, 'Proveedor2', '2023-07-20', 'Almacén A')
# (9861, 'Artículo9861', 'Moda', 428.14, 32, 'Proveedor1', '2023-01-16', 'Almacén A')
# (9862, 'Objeto9862', 'Deportes', 52.93, 60, 'Proveedor1', '2023-05-04', 'Almacén B')
# (9863, 'Objeto9863', 'Jardín', 300.88, 83, 'Proveedor2', '2023-06-10', 'Almacén B')
# (9864, 'Artículo9864', 'Deportes', 151.71, 65, 'Proveedor3', '2023-11-17', 'Almacén B')
# (9865, 'Artículo9865', 'Deportes', 259.98, 57, 'Proveedor1', '2023-10-07', 'Almacén A')
# (9866, 'Objeto9866', 'Jardín', 466.9, 66, 'Proveedor2', '2023-05-16', 'Almacén A')
# (9867, 'Producto9867', 'Hogar', 129.85, 84, 'Proveedor2', '2023-08-22', 'Almacén A')
# (9868, 'Artículo9868', 'Jardín', 475.29, 61, 'Proveedor2', '2023-10-07', 'Almacén A')
# (9869, 'Artículo9869', 'Deportes', 113.7, 100, 'Proveedor1', '2023-01-28', 'Almacén C')
# (9870, 'Producto9870', 'Electrónica', 301.38, 23, 'Proveedor2', '2023-07-21', 'Almacén B')
# (9871, 'Objeto9871', 'Hogar', 371.04, 48, 'Proveedor1', '2023-10-20', 'Almacén B')
# (9872, 'Objeto9872', 'Deportes', 288, 40, 'Proveedor2', '2023-08-13', 'Almacén A')
# (9873, 'Objeto9873', 'Moda', 86.73, 58, 'Proveedor1', '2023-01-24', 'Almacén A')
# (9874, 'Producto9874', 'Hogar', 117.19, 77, 'Proveedor1', '2023-07-13', 'Almacén C')
# (9875, 'Objeto9875', 'Hogar', 136.71, 90, 'Proveedor3', '2023-11-27', 'Almacén C')
# (9876, 'Producto9876', 'Electrónica', 101.29, 49, 'Proveedor2', '2023-09-14', 'Almacén C')
# (9877, 'Artículo9877', 'Moda', 167.45, 36, 'Proveedor1', '2023-01-16', 'Almacén B')
# (9878, 'Objeto9878', 'Moda', 397.58, 82, 'Proveedor2', '2023-11-18', 'Almacén B')
# (9879, 'Artículo9879', 'Jardín', 315.22, 9, 'Proveedor2', '2023-03-10', 'Almacén B')
# (9880, 'Artículo9880', 'Hogar', 349.12, 20, 'Proveedor1', '2023-02-18', 'Almacén B')
# (9881, 'Objeto9881', 'Jardín', 453.03, 64, 'Proveedor3', '2023-08-14', 'Almacén B')
# (9882, 'Artículo9882', 'Jardín', 41.46, 46, 'Proveedor3', '2023-01-02', 'Almacén A')
# (9883, 'Objeto9883', 'Moda', 243.93, 43, 'Proveedor1', '2023-08-22', 'Almacén A')
# (9884, 'Producto9884', 'Jardín', 241.42, 24, 'Proveedor3', '2023-01-20', 'Almacén B')
# (9885, 'Artículo9885', 'Electrónica', 115.35, 62, 'Proveedor1', '2023-03-14', 'Almacén C')
# (9886, 'Producto9886', 'Deportes', 320.37, 7, 'Proveedor2', '2023-05-24', 'Almacén A')
# (9887, 'Artículo9887', 'Jardín', 299.8, 88, 'Proveedor1', '2023-07-14', 'Almacén B')
# (9888, 'Objeto9888', 'Jardín', 242.8, 59, 'Proveedor2', '2023-05-01', 'Almacén C')
# (9889, 'Producto9889', 'Jardín', 75.08, 25, 'Proveedor2', '2023-07-26', 'Almacén B')
# (9890, 'Artículo9890', 'Moda', 73.05, 14, 'Proveedor1', '2023-05-05', 'Almacén C')
# (9891, 'Producto9891', 'Hogar', 394.34, 84, 'Proveedor3', '2023-06-19', 'Almacén A')
# (9892, 'Artículo9892', 'Electrónica', 410.54, 70, 'Proveedor2', '2023-09-14', 'Almacén B')
# (9893, 'Producto9893', 'Moda', 425.01, 15, 'Proveedor3', '2023-10-02', 'Almacén B')
# (9894, 'Artículo9894', 'Hogar', 379.87, 3, 'Proveedor2', '2023-06-08', 'Almacén A')
# (9895, 'Artículo9895', 'Hogar', 359.8, 63, 'Proveedor2', '2023-12-05', 'Almacén A')
# (9896, 'Objeto9896', 'Electrónica', 181.54, 1, 'Proveedor1', '2023-05-24', 'Almacén C')
# (9897, 'Producto9897', 'Deportes', 177.53, 62, 'Proveedor2', '2023-02-17', 'Almacén A')
# (9898, 'Producto9898', 'Moda', 385.99, 90, 'Proveedor3', '2023-08-24', 'Almacén C')
# (9899, 'Artículo9899', 'Jardín', 105.95, 7, 'Proveedor2', '2023-02-26', 'Almacén C')
# (9900, 'Objeto9900', 'Moda', 262.35, 90, 'Proveedor1', '2023-04-05', 'Almacén C')
# (9901, 'Artículo9901', 'Electrónica', 472.4, 49, 'Proveedor1', '2023-12-13', 'Almacén B')
# (9902, 'Objeto9902', 'Moda', 350.21, 52, 'Proveedor1', '2023-12-27', 'Almacén C')
# (9903, 'Objeto9903', 'Moda', 236.63, 67, 'Proveedor3', '2023-11-06', 'Almacén B')
# (9904, 'Producto9904', 'Electrónica', 480.29, 41, 'Proveedor1', '2023-09-15', 'Almacén A')
# (9905, 'Artículo9905', 'Jardín', 81.26, 10, 'Proveedor2', '2023-09-13', 'Almacén A')
# (9906, 'Producto9906', 'Hogar', 163.11, 52, 'Proveedor2', '2023-10-13', 'Almacén C')
# (9907, 'Objeto9907', 'Deportes', 456.3, 14, 'Proveedor2', '2023-03-11', 'Almacén C')
# (9908, 'Objeto9908', 'Hogar', 222.28, 35, 'Proveedor3', '2023-11-03', 'Almacén C')
# (9909, 'Objeto9909', 'Hogar', 188.45, 62, 'Proveedor2', '2023-02-10', 'Almacén C')
# (9910, 'Objeto9910', 'Hogar', 69.54, 73, 'Proveedor3', '2023-11-23', 'Almacén C')
# (9911, 'Producto9911', 'Electrónica', 26.86, 14, 'Proveedor2', '2023-01-20', 'Almacén A')
# (9912, 'Artículo9912', 'Deportes', 327.12, 1, 'Proveedor1', '2023-04-21', 'Almacén A')
# (9913, 'Producto9913', 'Moda', 174.74, 84, 'Proveedor2', '2023-02-06', 'Almacén A')
# (9914, 'Artículo9914', 'Deportes', 128.67, 24, 'Proveedor2', '2023-03-10', 'Almacén A')
# (9915, 'Objeto9915', 'Electrónica', 492.82, 11, 'Proveedor3', '2023-04-08', 'Almacén A')
# (9916, 'Objeto9916', 'Electrónica', 453.31, 48, 'Proveedor3', '2023-08-18', 'Almacén A')
# (9917, 'Producto9917', 'Moda', 187.8, 61, 'Proveedor1', '2023-05-16', 'Almacén A')
# (9918, 'Objeto9918', 'Electrónica', 140.99, 85, 'Proveedor3', '2023-12-03', 'Almacén A')
# (9919, 'Objeto9919', 'Moda', 215.61, 15, 'Proveedor1', '2023-01-27', 'Almacén A')
# (9920, 'Artículo9920', 'Electrónica', 329.83, 46, 'Proveedor1', '2023-07-06', 'Almacén A')
# (9921, 'Producto9921', 'Deportes', 433.54, 99, 'Proveedor3', '2023-03-24', 'Almacén C')
# (9922, 'Producto9922', 'Electrónica', 18.31, 9, 'Proveedor3', '2023-11-24', 'Almacén C')
# (9923, 'Artículo9923', 'Moda', 24.74, 37, 'Proveedor1', '2023-09-20', 'Almacén B')
# (9924, 'Objeto9924', 'Hogar', 111.14, 32, 'Proveedor3', '2023-07-16', 'Almacén C')
# (9925, 'Artículo9925', 'Moda', 53.52, 96, 'Proveedor1', '2023-05-11', 'Almacén A')
# (9926, 'Artículo9926', 'Electrónica', 324.32, 92, 'Proveedor2', '2023-10-28', 'Almacén C')
# (9927, 'Artículo9927', 'Jardín', 145.38, 37, 'Proveedor1', '2023-01-05', 'Almacén B')
# (9928, 'Objeto9928', 'Moda', 44.82, 23, 'Proveedor1', '2023-08-27', 'Almacén C')
# (9929, 'Objeto9929', 'Jardín', 115.78, 23, 'Proveedor1', '2023-01-24', 'Almacén C')
# (9930, 'Objeto9930', 'Moda', 426.49, 90, 'Proveedor3', '2023-07-04', 'Almacén B')
# (9931, 'Objeto9931', 'Jardín', 152.3, 9, 'Proveedor3', '2023-08-07', 'Almacén B')
# (9932, 'Artículo9932', 'Deportes', 47.26, 22, 'Proveedor2', '2023-05-18', 'Almacén B')
# (9933, 'Producto9933', 'Electrónica', 212.36, 70, 'Proveedor2', '2023-12-18', 'Almacén B')
# (9934, 'Objeto9934', 'Moda', 22.78, 82, 'Proveedor2', '2023-08-07', 'Almacén C')
# (9935, 'Objeto9935', 'Jardín', 320.12, 95, 'Proveedor1', '2023-08-19', 'Almacén A')
# (9936, 'Producto9936', 'Jardín', 74.5, 58, 'Proveedor1', '2023-05-05', 'Almacén C')
# (9937, 'Objeto9937', 'Electrónica', 364.89, 4, 'Proveedor3', '2023-02-13', 'Almacén A')
# (9938, 'Producto9938', 'Moda', 25.82, 30, 'Proveedor3', '2023-01-20', 'Almacén B')
# (9939, 'Artículo9939', 'Jardín', 217.59, 61, 'Proveedor1', '2023-07-18', 'Almacén C')
# (9940, 'Artículo9940', 'Electrónica', 175.27, 5, 'Proveedor1', '2023-01-10', 'Almacén A')
# (9941, 'Artículo9941', 'Hogar', 254.31, 98, 'Proveedor2', '2023-03-01', 'Almacén B')
# (9942, 'Artículo9942', 'Moda', 42.19, 73, 'Proveedor1', '2023-02-20', 'Almacén A')
# (9943, 'Artículo9943', 'Moda', 30.21, 52, 'Proveedor3', '2023-05-17', 'Almacén B')
# (9944, 'Objeto9944', 'Moda', 250.19, 77, 'Proveedor1', '2023-05-10', 'Almacén B')
# (9945, 'Objeto9945', 'Hogar', 168.89, 69, 'Proveedor2', '2023-10-11', 'Almacén C')
# (9946, 'Artículo9946', 'Hogar', 139.81, 59, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9947, 'Artículo9947', 'Jardín', 420.53, 40, 'Proveedor3', '2023-06-19', 'Almacén A')
# (9948, 'Producto9948', 'Electrónica', 232.26, 65, 'Proveedor3', '2023-06-23', 'Almacén C')
# (9949, 'Objeto9949', 'Deportes', 20.65, 52, 'Proveedor2', '2023-03-24', 'Almacén B')
# (9950, 'Objeto9950', 'Hogar', 282.87, 44, 'Proveedor3', '2023-07-09', 'Almacén A')
# (9951, 'Objeto9951', 'Electrónica', 387.73, 2, 'Proveedor1', '2023-09-01', 'Almacén B')
# (9952, 'Objeto9952', 'Deportes', 16.42, 51, 'Proveedor3', '2023-01-15', 'Almacén A')
# (9953, 'Producto9953', 'Jardín', 212.33, 30, 'Proveedor1', '2023-05-17', 'Almacén B')
# (9954, 'Artículo9954', 'Jardín', 456.19, 81, 'Proveedor3', '2023-07-02', 'Almacén B')
# (9955, 'Producto9955', 'Electrónica', 40.7, 41, 'Proveedor1', '2023-04-04', 'Almacén C')
# (9956, 'Producto9956', 'Electrónica', 438.99, 21, 'Proveedor3', '2023-03-04', 'Almacén A')
# (9957, 'Artículo9957', 'Jardín', 294.82, 44, 'Proveedor1', '2023-12-23', 'Almacén A')
# (9958, 'Producto9958', 'Hogar', 256.95, 57, 'Proveedor1', '2023-11-18', 'Almacén A')
# (9959, 'Artículo9959', 'Electrónica', 207.4, 28, 'Proveedor1', '2023-11-14', 'Almacén A')
# (9960, 'Objeto9960', 'Deportes', 485.02, 96, 'Proveedor2', '2023-02-18', 'Almacén B')
# (9961, 'Producto9961', 'Hogar', 469.96, 36, 'Proveedor2', '2023-04-13', 'Almacén B')
# (9962, 'Artículo9962', 'Jardín', 28.51, 95, 'Proveedor3', '2023-01-09', 'Almacén A')
# (9963, 'Producto9963', 'Hogar', 98.37, 17, 'Proveedor1', '2023-04-13', 'Almacén C')
# (9964, 'Producto9964', 'Hogar', 292.48, 4, 'Proveedor3', '2023-02-16', 'Almacén C')
# (9965, 'Producto9965', 'Moda', 451.16, 61, 'Proveedor3', '2023-12-25', 'Almacén C')
# (9966, 'Artículo9966', 'Jardín', 242.75, 20, 'Proveedor1', '2023-08-17', 'Almacén C')
# (9967, 'Artículo9967', 'Hogar', 108.2, 93, 'Proveedor3', '2023-01-14', 'Almacén C')
# (9968, 'Producto9968', 'Electrónica', 293.72, 60, 'Proveedor3', '2023-03-11', 'Almacén A')
# (9969, 'Artículo9969', 'Jardín', 84.61, 53, 'Proveedor3', '2023-10-06', 'Almacén A')
# (9970, 'Objeto9970', 'Electrónica', 250.16, 12, 'Proveedor3', '2023-09-20', 'Almacén A')
# (9971, 'Objeto9971', 'Jardín', 334.69, 57, 'Proveedor2', '2023-06-28', 'Almacén B')
# (9972, 'Producto9972', 'Deportes', 71.76, 10, 'Proveedor1', '2023-02-08', 'Almacén B')
# (9973, 'Objeto9973', 'Moda', 343.21, 63, 'Proveedor2', '2023-07-09', 'Almacén A')
# (9974, 'Artículo9974', 'Moda', 362.86, 60, 'Proveedor1', '2023-08-03', 'Almacén C')
# (9975, 'Objeto9975', 'Moda', 93.85, 27, 'Proveedor3', '2023-09-24', 'Almacén C')
# (9976, 'Objeto9976', 'Hogar', 436.91, 44, 'Proveedor2', '2023-09-25', 'Almacén A')
# (9977, 'Producto9977', 'Jardín', 272.09, 49, 'Proveedor3', '2023-12-22', 'Almacén C')
# (9978, 'Producto9978', 'Electrónica', 82.01, 94, 'Proveedor3', '2023-09-20', 'Almacén B')
# (9979, 'Artículo9979', 'Jardín', 256.98, 39, 'Proveedor2', '2023-08-18', 'Almacén C')
# (9980, 'Objeto9980', 'Hogar', 121.63, 60, 'Proveedor3', '2023-10-24', 'Almacén C')
# (9981, 'Producto9981', 'Hogar', 318.27, 5, 'Proveedor1', '2023-02-23', 'Almacén B')
# (9982, 'Artículo9982', 'Electrónica', 490.81, 25, 'Proveedor3', '2023-10-24', 'Almacén C')
# (9983, 'Artículo9983', 'Jardín', 146.62, 73, 'Proveedor2', '2023-08-18', 'Almacén B')
# (9984, 'Producto9984', 'Jardín', 419.31, 68, 'Proveedor2', '2023-02-22', 'Almacén B')
# (9985, 'Producto9985', 'Moda', 60.79, 75, 'Proveedor2', '2023-02-20', 'Almacén B')
# (9986, 'Artículo9986', 'Moda', 295.01, 59, 'Proveedor2', '2023-06-17', 'Almacén A')
# (9987, 'Objeto9987', 'Moda', 166.41, 22, 'Proveedor2', '2023-05-17', 'Almacén C')
# (9988, 'Artículo9988', 'Electrónica', 284.23, 27, 'Proveedor3', '2023-11-22', 'Almacén B')
# (9989, 'Artículo9989', 'Jardín', 461.95, 77, 'Proveedor3', '2023-12-09', 'Almacén A')
# (9990, 'Objeto9990', 'Moda', 383.05, 20, 'Proveedor1', '2023-11-19', 'Almacén B')
# (9991, 'Artículo9991', 'Jardín', 178.59, 65, 'Proveedor1', '2023-06-14', 'Almacén B')
# (9992, 'Producto9992', 'Electrónica', 341.1, 1, 'Proveedor1', '2023-01-11', 'Almacén A')
# (9993, 'Producto9993', 'Electrónica', 388.25, 71, 'Proveedor1', '2023-07-01', 'Almacén B')
# (9994, 'Producto9994', 'Electrónica', 180.12, 62, 'Proveedor1', '2023-12-05', 'Almacén C')
# (9995, 'Producto9995', 'Electrónica', 348.55, 72, 'Proveedor1', '2023-07-10', 'Almacén B')
# (9996, 'Artículo9996', 'Jardín', 183.18, 27, 'Proveedor3', '2023-03-18', 'Almacén C')
# (9997, 'Objeto9997', 'Hogar', 231, 81, 'Proveedor3', '2023-09-13', 'Almacén A')
# (9998, 'Artículo9998', 'Moda', 218.47, 87, 'Proveedor1', '2023-04-24', 'Almacén C')
# (9999, 'Producto9999', 'Deportes', 183.71, 63, 'Proveedor1', '2023-03-14', 'Almacén B')
# (10000, 'Objeto10000', 'Moda', 185.75, 16, 'Proveedor3', '2023-07-19', 'Almacén B')

# %% [markdown]
# Consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#         id        nombre    categoria  precio  cantidad   proveedor  \
# 0        3     Producto3         Moda  498.68        81  Proveedor1
# 1       14      Objeto14     Deportes  464.14        26  Proveedor2
# 2       28    Producto28       Jardín  483.15        57  Proveedor1
# 3       36    Artículo36     Deportes  490.18        80  Proveedor3
# 4       62    Producto62         Moda  498.59         7  Proveedor2
# ...    ...           ...          ...     ...       ...         ...
# 1034  9960    Objeto9960     Deportes  485.02        96  Proveedor2
# 1035  9961  Producto9961        Hogar  469.96        36  Proveedor2
# 1036  9965  Producto9965         Moda  451.16        61  Proveedor3
# 1037  9982  Artículo9982  Electrónica  490.81        25  Proveedor3
# 1038  9989  Artículo9989       Jardín  461.95        77  Proveedor3
#
#      fecha_ingreso  ubicacion
# 0       2023-02-04  Almacén B
# 1       2023-02-24  Almacén B
# 2       2023-11-22  Almacén A
# 3       2023-04-18  Almacén A
# 4       2023-12-11  Almacén B
# ...            ...        ...
# 1034    2023-02-18  Almacén B
# 1035    2023-04-13  Almacén B
# 1036    2023-12-25  Almacén C
# 1037    2023-10-24  Almacén C
# 1038    2023-12-09  Almacén A
#
# [1039 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0   3   Producto3      Moda  498.68        81  Proveedor1    2023-02-04
# 1  14    Objeto14  Deportes  464.14        26  Proveedor2    2023-02-24
# 2  28  Producto28    Jardín  483.15        57  Proveedor1    2023-11-22
# 3  36  Artículo36  Deportes  490.18        80  Proveedor3    2023-04-18
# 4  62  Producto62      Moda  498.59         7  Proveedor2    2023-12-11
#
#    ubicacion
# 0  Almacén B
# 1  Almacén B
# 2  Almacén A
# 3  Almacén A
# 4  Almacén B

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id        nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0       3     Producto3      Moda  498.68        81  Proveedor1    2023-02-04
# 1      14      Objeto14  Deportes  464.14        26  Proveedor2    2023-02-24
# 2      28    Producto28    Jardín  483.15        57  Proveedor1    2023-11-22
# 3      36    Artículo36  Deportes  490.18        80  Proveedor3    2023-04-18
# 4      64      Objeto64     Hogar  481.92        79  Proveedor3    2023-05-12
# ..    ...           ...       ...     ...       ...         ...           ...
# 749  9954  Artículo9954    Jardín  456.19        81  Proveedor3    2023-07-02
# 750  9960    Objeto9960  Deportes  485.02        96  Proveedor2    2023-02-18
# 751  9961  Producto9961     Hogar  469.96        36  Proveedor2    2023-04-13
# 752  9965  Producto9965      Moda  451.16        61  Proveedor3    2023-12-25
# 753  9989  Artículo9989    Jardín  461.95        77  Proveedor3    2023-12-09
#
#      ubicacion
# 0    Almacén B
# 1    Almacén B
# 2    Almacén A
# 3    Almacén A
# 4    Almacén A
# ..         ...
# 749  Almacén B
# 750  Almacén B
# 751  Almacén B
# 752  Almacén C
# 753  Almacén A
#
# [754 rows x 8 columns]

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-01 20:44:23.560514  Almacén B
# 1 2025-03-06 20:44:23.560562  Almacén C
# 2 2024-12-12 20:44:23.560576  Almacén B
# 3 2025-08-09 20:44:23.560587  Almacén A
# 4 2024-11-25 20:44:23.560596  Almacén A

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-01 20:44:23.561  Almacén B
# 1 2025-03-06 20:44:23.561  Almacén C
# 2 2024-12-12 20:44:23.561  Almacén B
# 3 2025-08-09 20:44:23.561  Almacén A
# 4 2024-11-25 20:44:23.561  Almacén A

# %%
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)""", (None, row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']))


# # Insersión de datos en la DB
# for index, row in df.iterrows():
#     c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipython-input-2974431415.py in <cell line: 0>()
#       7 # Insersión de datos en la DB
#       8 for index, row in df.iterrows():
# ----> 9     c.execute("""
#      10         INSERT INTO inventario (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#      11         VALUES (?, ?, ?, ?, ?, ?, ?, ?)""", (None, row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']))
#
# ProgrammingError: Error binding parameter 7: type 'Timestamp' is not supported
